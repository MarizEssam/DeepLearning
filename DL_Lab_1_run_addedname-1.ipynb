# %% [markdown]
# ###Mariz Essam Sobhy Ghaly
# ##1808421
# ## CSE 477s Lab 1
# ### TensorFlow 2 Tutorial: Get Started in Deep Learning With tf.keras

# %%
#Mariz Essam Sobhy Ghaly
#1808421

# %% [markdown]
# TensorFlow is the premier open-source deep learning framework developed and maintained by
# Google. Although using TensorFlow directly can be challenging, the modern tf.keras API beings
# the simplicity and ease of use of Keras to the TensorFlow project.
#
# Using tf.keras allows you to design, fit, evaluate, and use deep learning models to make
# predictions in just a few lines of code. It makes common deep learning tasks, such as
# classification and regression predictive modeling, accessible to average developers looking to
# get things done.
#
# In this tutorial, you will discover a step-by-step guide to developing deep learning models in
# TensorFlow using the tf.keras API.

# %% [markdown]
# ### Install TensorFlow and tf.keras
# In this section, you will discover what tf.keras is, how to install it, and how to confirm that it
# is installed correctly.

# %% [markdown]
# #### 1.1 What Are Keras and tf.keras?
# Keras is an open-source deep learning library written in Python.
#
# The project was started in 2015 by Francois Chollet. It quickly became a popular framework
# for developers, becoming one of, if not the most, popular deep learning libraries.
#
# During the period of 2015-2019, developing deep learning models using mathematical
# libraries like TensorFlow, Theano, and PyTorch was cumbersome, requiring tens or even
# hundreds of lines of code to achieve the simplest tasks. The focus of these libraries was on
# research, flexibility, and speed, not ease of use.
#
# Keras was popular because the API was clean and simple, allowing standard deep learning
# models to be defined, fit, and evaluated in just a few lines of code.
#
# A secondary reason Keras took-off was because it allowed you to use any one among the
# range of popular deep learning mathematical libraries as the backend (e.g. used to perform
# the computation), such as TensorFlow, Theano, and later, CNTK. This allowed the power of
# these libraries to be harnessed (e.g. GPUs) with a very clean and simple interface.
#
# In 2019, Google released a new version of their TensorFlow deep learning library
# (TensorFlow 2) that integrated the Keras API directly and promoted this interface as the
# default or standard interface for deep learning development on the platform.
# This integration is commonly referred to as the tf.keras interface or API (“tf” is short for
# “TensorFlow“).
#
# This is to distinguish it from the so-called standalone Keras open source project.
# * Standalone Keras. The standalone open source project that supports TensorFlow,
# Theano and CNTK backends.
# * tf.keras. The Keras API integrated into TensorFlow 2.
#
# The Keras API implementation in Keras is referred to as “tf.keras” because this is the
# Python idiom used when referencing the API. First, the TensorFlow module is imported and
# named “tf“; then, Keras API elements are accessed via calls to tf.keras; for example:

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.10.0'

# %%
import tensorflow.keras as keras

# %%
K.__version__
# Out:
# '2.10.0'

# %%
# example of tf.keras python idiom
import tensorflow as tf
# use keras API
model = keras.Sequential()
# Out:
# Metal device set to: Apple M1 Max
# 2022-10-09 17:58:33.215841: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-09 17:58:33.216499: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# Given that TensorFlow was the de facto standard backend for the Keras open source
# project, the integration means that a single library can now be used instead of two separate
# libraries. Further, the standalone Keras project now recommends all future Keras
# development use the tf.keras API.

# %% [markdown]
# #### How to Install TensorFlow
# Before installing TensorFlow, ensure that you have Python installed, such as Python 3.6 or
# higher.
#
# There are many ways to install the TensorFlow open-source deep learning library.
# The most common, and perhaps the simplest, way to install TensorFlow on your
# workstation is by using pip.
#
# For example, on the command line, you can type:
# `sudo pip install tensorflow`

# %% [markdown]
# #### How to Confirm TensorFlow Is Installed
# Once TensorFlow is installed, it is important to confirm that the library was installed
# successfully and that you can start using it.
#
# Don’t skip this step.
# If TensorFlow is not installed correctly or raises an error on this step, you won’t be able to
# run the examples later.
#
# Create a new file called versions.py and copy and paste the following code into the file.

# %%
# check version
import tensorflow
print(tensorflow.__version__)

# %% [markdown]
# ### Deep Learning Model Life-Cycle
#
# In this section, you will discover the life-cycle for a deep learning model and the two tf.keras
# APIs that you can use to define models.
#
# #### The 5-Step Model Life-Cycle
# A model has a life-cycle, and this very simple knowledge provides the backbone for both
# modeling a dataset and understanding the tf.keras API.
# The five steps in the life-cycle are as follows:
# 1. Define the model.
# 2. Compile the model.
# 3. Fit the model.
# 4. Evaluate the model.
# 5. Make predictions.
# Let’s take a closer look at each step in turn.
#
# ##### Define the Model
# Defining the model requires that you first select the type of model that you need and then
# choose the architecture or network topology.
# From an API perspective, this involves defining the layers of the model, configuring each
# layer with a number of nodes and activation function, and connecting the layers together
# into a cohesive model.
# Models can be defined either with the Sequential API or the Functional API, and we will take
# a look at this in the next section.

# %%
# define the model
model = #..

# %% [markdown]
# ##### Compile the Model
# Compiling the model requires that you first select a loss function that you want to optimize,
# such as mean squared error or cross-entropy.
#
# It also requires that you select an algorithm to perform the optimization procedure, typically
# stochastic gradient descent, or a modern variation, such as Adam. It may also require that
# you select any performance metrics to keep track of during the model training process.
#
# From an API perspective, this involves calling a function to compile the model with the
# chosen configuration, which will prepare the appropriate data structures required for the
# efficient use of the model you have defined.
#
# The optimizer can be specified as a string for a known optimizer class, e.g. `sgd` for
# stochastic gradient descent, or you can configure an instance of an optimizer class and use
# that.
#
# For a list of supported optimizers, see [this](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers):

# %%
# compile the model
opt = SGD(learning_rate=0.01, momentum=0.9)
model.compile(optimizer=opt, loss='binary_crossentropy')

# %% [markdown]
# The three most common loss functions are:
# * ‘binary_crossentropy‘ for binary classification.
# * ‘sparse_categorical_crossentropy‘ for multi-class classification.
# * ‘mse‘ (mean squared error) for regression.

# %%
# compile the model
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# For a list of supported loss functions, see: [tf.keras Loss Functions](https://www.tensorflow.org/api_docs/python/tf/keras/losses)
#
# Metrics are defined as a list of strings for known metric functions or a list of functions to call
# to evaluate predictions.
#
# For a list of supported metrics, see: [tf.keras Metrics](https://www.tensorflow.org/api_docs/python/tf/keras/metrics)

# %%
# compile the model
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ##### Fit the Model
# Fitting the model requires that you first select the training configuration, such as the number
# of epochs (loops through the training dataset) and the batch size (number of samples in an
# epoch used to estimate model error).
#
# Training applies the chosen optimization algorithm to minimize the chosen loss function and
# updates the model using the backpropagation of error algorithm.
#
# Fitting the model is the slow part of the whole process and can take seconds to hours to
# days, depending on the complexity of the model, the hardware you’re using, and the size of
# the training dataset.
#
# From an API perspective, this involves calling a function to perform the training process.
# This function will block (not return) until the training process has finished.

# %%
# fit the model
model.fit(X, y, epochs=100, batch_size=32)

# %% [markdown]
# While fitting the model, a progress bar will summarize the status of each epoch and the
# overall training process. This can be simplified to a simple report of model performance
# each epoch by setting the “verbose” argument to 2. All output can be turned off during
# training by setting “verbose” to 0.

# %%
# fit the model
model.fit(X, y, epochs=100, batch_size=32, verbose=0)

# %% [markdown]
# #### Evaluate the Model
# Evaluating the model requires that you first choose a holdout dataset used to evaluate the
# model. This should be data not used in the training process so that we can get an unbiased
# estimate of the performance of the model when making predictions on new data.
#
# The speed of model evaluation is proportional to the amount of data you want to use for the
# evaluation, although it is much faster than training as the model is not changed.
#
# From an API perspective, this involves calling a function with the holdout dataset and
# getting a loss and perhaps other metrics that can be reported.

# %%
# evaluate the model
loss = model.evaluate(X, y, verbose=0)

# %% [markdown]
# #### Make a Prediction
# Making a prediction is the final step in the life-cycle. It is why we wanted the model in the
# first place.
#
# It requires you have new data for which a prediction is required, e.g. where you do not have
# the target values.
#
# From an API perspective, you simply call a function to make a prediction of a class label,
# probability, or numerical value: whatever you designed your model to predict.
#
# You may want to save the model and later load it to make predictions. You may also choose
# to fit a model on all of the available data before you start using it.
#
# Now that we are familiar with the model life-cycle, let’s take a look at the two main ways to
# use the tf.keras API to build models: sequential and functional.

# %%
# make a prediction
yhat = model.predict(X)

# %%
# example of tf.keras python idiom
import tensorflow as tf
# use keras API
model = tf.keras.Sequential()

# %%
tf.__version__
# Out:
# '2.9.2'

# %% [markdown]
# ## Example one - Classification

# %%
# mlp for multiclass classification
from numpy import argmax
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# load the dataset
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv'
df = read_csv(path, header=None)
# split into input and output columns
X, y = df.values[:, :-1], df.values[:, -1]
# ensure all data are floating point values
X = X.astype('float32')
# encode strings to integer
y = LabelEncoder().fit_transform(y)
# split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# determine the number of input features
n_features = X_train.shape[1]
# Out:
# (100, 4) (50, 4) (100,) (50,)

# %%
# define model
model = Sequential()
model.add(Dense(10, activation='relu', kernel_initializer='he_normal',
input_shape=(n_features,)))
model.add(Dense(8, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(3, activation='softmax'))

# compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# fit the model
model.fit(X_train, y_train, epochs=150, batch_size=32, verbose=0)

# evaluate the model
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)

# make a prediction
row = [5.1,3.5,1.4,0.2]
yhat = model.predict([row])
print('Predicted: %s (class=%d)' % (yhat, argmax(yhat)))
# Out:
# 2022-10-09 18:37:25.888909: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Test Accuracy: 0.680
# 1/1 [==============================] - 0s 39ms/step
# Predicted: [[0.44290495 0.34628588 0.21080919]] (class=0)
# 2022-10-09 18:37:29.063110: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-10-09 18:37:29.165201: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# ## Example two - Regression

# %%
# mlp for regression
from numpy import sqrt
from pandas import read_csv
from sklearn.model_selection import train_test_split
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# load the dataset
path = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
df = read_csv(path, header=None)
# split into input and output columns
X, y = df.values[:, :-1], df.values[:, -1]
# split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# determine the number of input features
n_features = X_train.shape[1]

# define model
model = Sequential()
model.add(Dense(10, activation="relu", input_shape=(n_features,)))
model.add(Dense(8, activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(1))

# compile the model
model.compile(optimizer='adam', loss='mse')

# fit the model
model.fit(X_train, y_train, epochs=1500, batch_size=32, verbose=2)

# evaluate the model
error = model.evaluate(X_test, y_test, verbose=0)
print('MSE: %.3f, RMSE: %.3f' % (error, sqrt(error)))
# make a prediction
row = [0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,396.90,4.98]
yhat = model.predict([row])
print('Predicted: %.3f' % yhat)
# Out:
# (339, 13) (167, 13) (339,) (167,)
# Epoch 1/1500
# 11/11 - 1s - loss: 3174.9048 - 563ms/epoch - 51ms/step
# Epoch 2/1500
# 11/11 - 0s - loss: 789.0365 - 13ms/epoch - 1ms/step
# Epoch 3/1500
# 11/11 - 0s - loss: 175.1325 - 12ms/epoch - 1ms/step
# Epoch 4/1500
# 11/11 - 0s - loss: 166.1245 - 14ms/epoch - 1ms/step
# Epoch 5/1500
# 11/11 - 0s - loss: 159.3141 - 15ms/epoch - 1ms/step
# Epoch 6/1500
# 11/11 - 0s - loss: 131.9377 - 16ms/epoch - 1ms/step
# Epoch 7/1500
# 11/11 - 0s - loss: 126.6773 - 14ms/epoch - 1ms/step
# Epoch 8/1500
# 11/11 - 0s - loss: 123.3249 - 13ms/epoch - 1ms/step
# Epoch 9/1500
# 11/11 - 0s - loss: 119.6557 - 13ms/epoch - 1ms/step
# Epoch 10/1500
# 11/11 - 0s - loss: 116.8153 - 12ms/epoch - 1ms/step
# Epoch 11/1500
# 11/11 - 0s - loss: 113.9576 - 12ms/epoch - 1ms/step
# Epoch 12/1500
# 11/11 - 0s - loss: 110.9847 - 13ms/epoch - 1ms/step
# Epoch 13/1500
# 11/11 - 0s - loss: 108.1561 - 22ms/epoch - 2ms/step
# Epoch 14/1500
# 11/11 - 0s - loss: 105.8037 - 14ms/epoch - 1ms/step
# Epoch 15/1500
# 11/11 - 0s - loss: 103.6107 - 17ms/epoch - 2ms/step
# Epoch 16/1500
# 11/11 - 0s - loss: 100.9669 - 12ms/epoch - 1ms/step
# Epoch 17/1500
# 11/11 - 0s - loss: 98.9846 - 13ms/epoch - 1ms/step
# Epoch 18/1500
# 11/11 - 0s - loss: 97.0216 - 12ms/epoch - 1ms/step
# Epoch 19/1500
# 11/11 - 0s - loss: 95.1907 - 19ms/epoch - 2ms/step
# Epoch 20/1500
# 11/11 - 0s - loss: 93.5789 - 16ms/epoch - 1ms/step
# Epoch 21/1500
# 11/11 - 0s - loss: 91.9446 - 16ms/epoch - 1ms/step
# Epoch 22/1500
# 11/11 - 0s - loss: 90.4193 - 15ms/epoch - 1ms/step
# Epoch 23/1500
# 11/11 - 0s - loss: 89.0351 - 15ms/epoch - 1ms/step
# Epoch 24/1500
# 11/11 - 0s - loss: 87.6758 - 26ms/epoch - 2ms/step
# Epoch 25/1500
# 11/11 - 0s - loss: 86.5414 - 23ms/epoch - 2ms/step
# Epoch 26/1500
# 11/11 - 0s - loss: 85.2977 - 15ms/epoch - 1ms/step
# Epoch 27/1500
# 11/11 - 0s - loss: 84.3720 - 15ms/epoch - 1ms/step
# Epoch 28/1500
# 11/11 - 0s - loss: 82.9923 - 14ms/epoch - 1ms/step
# Epoch 29/1500
# 11/11 - 0s - loss: 82.0800 - 17ms/epoch - 2ms/step
# Epoch 30/1500
# 11/11 - 0s - loss: 81.1689 - 18ms/epoch - 2ms/step
# Epoch 31/1500
# 11/11 - 0s - loss: 80.4237 - 18ms/epoch - 2ms/step
# Epoch 32/1500
# 11/11 - 0s - loss: 79.5365 - 24ms/epoch - 2ms/step
# Epoch 33/1500
# 11/11 - 0s - loss: 78.5004 - 16ms/epoch - 1ms/step
# Epoch 34/1500
# 11/11 - 0s - loss: 78.1446 - 17ms/epoch - 2ms/step
# Epoch 35/1500
# 11/11 - 0s - loss: 77.9158 - 19ms/epoch - 2ms/step
# Epoch 36/1500
# 11/11 - 0s - loss: 76.4940 - 18ms/epoch - 2ms/step
# Epoch 37/1500
# 11/11 - 0s - loss: 76.2518 - 18ms/epoch - 2ms/step
# Epoch 38/1500
# 11/11 - 0s - loss: 75.6327 - 16ms/epoch - 1ms/step
# Epoch 39/1500
# 11/11 - 0s - loss: 75.1307 - 15ms/epoch - 1ms/step
# Epoch 40/1500
# 11/11 - 0s - loss: 74.7870 - 15ms/epoch - 1ms/step
# Epoch 41/1500
# 11/11 - 0s - loss: 74.4095 - 15ms/epoch - 1ms/step
# Epoch 42/1500
# 11/11 - 0s - loss: 74.1263 - 15ms/epoch - 1ms/step
# Epoch 43/1500
# 11/11 - 0s - loss: 73.1188 - 16ms/epoch - 1ms/step
# Epoch 44/1500
# 11/11 - 0s - loss: 73.6354 - 16ms/epoch - 1ms/step
# Epoch 45/1500
# 11/11 - 0s - loss: 72.6932 - 18ms/epoch - 2ms/step
# Epoch 46/1500
# 11/11 - 0s - loss: 72.2594 - 17ms/epoch - 2ms/step
# Epoch 47/1500
# 11/11 - 0s - loss: 71.6789 - 17ms/epoch - 2ms/step
# Epoch 48/1500
# 11/11 - 0s - loss: 71.5085 - 16ms/epoch - 1ms/step
# Epoch 49/1500
# 11/11 - 0s - loss: 70.9668 - 17ms/epoch - 2ms/step
# Epoch 50/1500
# 11/11 - 0s - loss: 70.8105 - 15ms/epoch - 1ms/step
# Epoch 51/1500
# 11/11 - 0s - loss: 70.3787 - 17ms/epoch - 2ms/step
# Epoch 52/1500
# 11/11 - 0s - loss: 70.0436 - 14ms/epoch - 1ms/step
# Epoch 53/1500
# 11/11 - 0s - loss: 69.5434 - 13ms/epoch - 1ms/step
# Epoch 54/1500
# 11/11 - 0s - loss: 69.1240 - 19ms/epoch - 2ms/step
# Epoch 55/1500
# 11/11 - 0s - loss: 68.8318 - 15ms/epoch - 1ms/step
# Epoch 56/1500
# 11/11 - 0s - loss: 68.8910 - 26ms/epoch - 2ms/step
# Epoch 57/1500
# 11/11 - 0s - loss: 68.1495 - 13ms/epoch - 1ms/step
# Epoch 58/1500
# 11/11 - 0s - loss: 68.1180 - 13ms/epoch - 1ms/step
# Epoch 59/1500
# 11/11 - 0s - loss: 67.7979 - 14ms/epoch - 1ms/step
# Epoch 60/1500
# 11/11 - 0s - loss: 67.3402 - 13ms/epoch - 1ms/step
# Epoch 61/1500
# 11/11 - 0s - loss: 66.9541 - 12ms/epoch - 1ms/step
# Epoch 62/1500
# 11/11 - 0s - loss: 66.6461 - 12ms/epoch - 1ms/step
# Epoch 63/1500
# 11/11 - 0s - loss: 66.4981 - 18ms/epoch - 2ms/step
# Epoch 64/1500
# 11/11 - 0s - loss: 66.3278 - 13ms/epoch - 1ms/step
# Epoch 65/1500
# 11/11 - 0s - loss: 65.6479 - 17ms/epoch - 2ms/step
# Epoch 66/1500
# 11/11 - 0s - loss: 66.2592 - 22ms/epoch - 2ms/step
# Epoch 67/1500
# 11/11 - 0s - loss: 66.1303 - 15ms/epoch - 1ms/step
# Epoch 68/1500
# 11/11 - 0s - loss: 64.9078 - 13ms/epoch - 1ms/step
# Epoch 69/1500
# 11/11 - 0s - loss: 64.7233 - 17ms/epoch - 2ms/step
# Epoch 70/1500
# 11/11 - 0s - loss: 64.6743 - 15ms/epoch - 1ms/step
# Epoch 71/1500
# 11/11 - 0s - loss: 64.0399 - 18ms/epoch - 2ms/step
# Epoch 72/1500
# 11/11 - 0s - loss: 63.9619 - 21ms/epoch - 2ms/step
# Epoch 73/1500
# 11/11 - 0s - loss: 63.5766 - 13ms/epoch - 1ms/step
# Epoch 74/1500
# 11/11 - 0s - loss: 63.3120 - 14ms/epoch - 1ms/step
# Epoch 75/1500
# 11/11 - 0s - loss: 63.0145 - 16ms/epoch - 1ms/step
# Epoch 76/1500
# 11/11 - 0s - loss: 62.8265 - 17ms/epoch - 2ms/step
# Epoch 77/1500
# 11/11 - 0s - loss: 62.7543 - 16ms/epoch - 1ms/step
# Epoch 78/1500
# 11/11 - 0s - loss: 62.8382 - 18ms/epoch - 2ms/step
# Epoch 79/1500
# 11/11 - 0s - loss: 62.5387 - 16ms/epoch - 1ms/step
# Epoch 80/1500
# 11/11 - 0s - loss: 61.7024 - 15ms/epoch - 1ms/step
# Epoch 81/1500
# 11/11 - 0s - loss: 61.7461 - 16ms/epoch - 1ms/step
# Epoch 82/1500
# 11/11 - 0s - loss: 61.2077 - 27ms/epoch - 2ms/step
# Epoch 83/1500
# 11/11 - 0s - loss: 61.0419 - 15ms/epoch - 1ms/step
# Epoch 84/1500
# 11/11 - 0s - loss: 61.0007 - 13ms/epoch - 1ms/step
# Epoch 85/1500
# 11/11 - 0s - loss: 61.9242 - 15ms/epoch - 1ms/step
# Epoch 86/1500
# 11/11 - 0s - loss: 60.6739 - 21ms/epoch - 2ms/step
# Epoch 87/1500
# 11/11 - 0s - loss: 60.1241 - 17ms/epoch - 2ms/step
# Epoch 88/1500
# 11/11 - 0s - loss: 60.0152 - 16ms/epoch - 1ms/step
# Epoch 89/1500
# 11/11 - 0s - loss: 59.9981 - 14ms/epoch - 1ms/step
# Epoch 90/1500
# 11/11 - 0s - loss: 59.4110 - 16ms/epoch - 1ms/step
# Epoch 91/1500
# 11/11 - 0s - loss: 59.4691 - 18ms/epoch - 2ms/step
# Epoch 92/1500
# 11/11 - 0s - loss: 59.1974 - 16ms/epoch - 1ms/step
# Epoch 93/1500
# 11/11 - 0s - loss: 58.8135 - 14ms/epoch - 1ms/step
# Epoch 94/1500
# 11/11 - 0s - loss: 59.3571 - 15ms/epoch - 1ms/step
# Epoch 95/1500
# 11/11 - 0s - loss: 59.0325 - 16ms/epoch - 1ms/step
# Epoch 96/1500
# 11/11 - 0s - loss: 58.8175 - 15ms/epoch - 1ms/step
# Epoch 97/1500
# 11/11 - 0s - loss: 57.8047 - 13ms/epoch - 1ms/step
# Epoch 98/1500
# 11/11 - 0s - loss: 58.0155 - 17ms/epoch - 2ms/step
# Epoch 99/1500
# 11/11 - 0s - loss: 57.5413 - 16ms/epoch - 1ms/step
# Epoch 100/1500
# 11/11 - 0s - loss: 57.5069 - 14ms/epoch - 1ms/step
# Epoch 101/1500
# 11/11 - 0s - loss: 57.0742 - 17ms/epoch - 2ms/step
# Epoch 102/1500
# 11/11 - 0s - loss: 56.8477 - 16ms/epoch - 1ms/step
# Epoch 103/1500
# 11/11 - 0s - loss: 56.6677 - 18ms/epoch - 2ms/step
# Epoch 104/1500
# 11/11 - 0s - loss: 56.5257 - 13ms/epoch - 1ms/step
# Epoch 105/1500
# 11/11 - 0s - loss: 56.2947 - 14ms/epoch - 1ms/step
# Epoch 106/1500
# 11/11 - 0s - loss: 56.0768 - 14ms/epoch - 1ms/step
# Epoch 107/1500
# 11/11 - 0s - loss: 56.2213 - 17ms/epoch - 2ms/step
# Epoch 108/1500
# 11/11 - 0s - loss: 55.6331 - 13ms/epoch - 1ms/step
# Epoch 109/1500
# 11/11 - 0s - loss: 55.7273 - 14ms/epoch - 1ms/step
# Epoch 110/1500
# 11/11 - 0s - loss: 55.2463 - 15ms/epoch - 1ms/step
# Epoch 111/1500
# 11/11 - 0s - loss: 55.1630 - 14ms/epoch - 1ms/step
# Epoch 112/1500
# 11/11 - 0s - loss: 54.9470 - 14ms/epoch - 1ms/step
# Epoch 113/1500
# 11/11 - 0s - loss: 54.9590 - 15ms/epoch - 1ms/step
# Epoch 114/1500
# 11/11 - 0s - loss: 54.6852 - 14ms/epoch - 1ms/step
# Epoch 115/1500
# 11/11 - 0s - loss: 54.6711 - 14ms/epoch - 1ms/step
# Epoch 116/1500
# 11/11 - 0s - loss: 54.3757 - 26ms/epoch - 2ms/step
# Epoch 117/1500
# 11/11 - 0s - loss: 54.1577 - 19ms/epoch - 2ms/step
# Epoch 118/1500
# 11/11 - 0s - loss: 53.7243 - 19ms/epoch - 2ms/step
# Epoch 119/1500
# 11/11 - 0s - loss: 53.8015 - 32ms/epoch - 3ms/step
# Epoch 120/1500
# 11/11 - 0s - loss: 55.0262 - 14ms/epoch - 1ms/step
# Epoch 121/1500
# 11/11 - 0s - loss: 54.2667 - 20ms/epoch - 2ms/step
# Epoch 122/1500
# 11/11 - 0s - loss: 53.1296 - 15ms/epoch - 1ms/step
# Epoch 123/1500
# 11/11 - 0s - loss: 53.0416 - 14ms/epoch - 1ms/step
# Epoch 124/1500
# 11/11 - 0s - loss: 52.6324 - 15ms/epoch - 1ms/step
# Epoch 125/1500
# 11/11 - 0s - loss: 52.6250 - 14ms/epoch - 1ms/step
# Epoch 126/1500
# 11/11 - 0s - loss: 52.3051 - 13ms/epoch - 1ms/step
# Epoch 127/1500
# 11/11 - 0s - loss: 52.2374 - 13ms/epoch - 1ms/step
# Epoch 128/1500
# 11/11 - 0s - loss: 51.8919 - 11ms/epoch - 1ms/step
# Epoch 129/1500
# 11/11 - 0s - loss: 52.0057 - 14ms/epoch - 1ms/step
# Epoch 130/1500
# 11/11 - 0s - loss: 51.8337 - 13ms/epoch - 1ms/step
# Epoch 131/1500
# 11/11 - 0s - loss: 52.1580 - 20ms/epoch - 2ms/step
# Epoch 132/1500
# 11/11 - 0s - loss: 51.2568 - 13ms/epoch - 1ms/step
# Epoch 133/1500
# 11/11 - 0s - loss: 51.2203 - 13ms/epoch - 1ms/step
# Epoch 134/1500
# 11/11 - 0s - loss: 51.1226 - 13ms/epoch - 1ms/step
# Epoch 135/1500
# 11/11 - 0s - loss: 50.9516 - 14ms/epoch - 1ms/step
# Epoch 136/1500
# 11/11 - 0s - loss: 50.7429 - 13ms/epoch - 1ms/step
# Epoch 137/1500
# 11/11 - 0s - loss: 50.7298 - 14ms/epoch - 1ms/step
# Epoch 138/1500
# 11/11 - 0s - loss: 50.3434 - 12ms/epoch - 1ms/step
# Epoch 139/1500
# 11/11 - 0s - loss: 50.6669 - 13ms/epoch - 1ms/step
# Epoch 140/1500
# 11/11 - 0s - loss: 50.4570 - 14ms/epoch - 1ms/step
# Epoch 141/1500
# 11/11 - 0s - loss: 49.9666 - 13ms/epoch - 1ms/step
# Epoch 142/1500
# 11/11 - 0s - loss: 50.3449 - 13ms/epoch - 1ms/step
# Epoch 143/1500
# 11/11 - 0s - loss: 49.3616 - 12ms/epoch - 1ms/step
# Epoch 144/1500
# 11/11 - 0s - loss: 49.2655 - 12ms/epoch - 1ms/step
# Epoch 145/1500
# 11/11 - 0s - loss: 49.2092 - 15ms/epoch - 1ms/step
# Epoch 146/1500
# 11/11 - 0s - loss: 48.7502 - 14ms/epoch - 1ms/step
# Epoch 147/1500
# 11/11 - 0s - loss: 48.6106 - 13ms/epoch - 1ms/step
# Epoch 148/1500
# 11/11 - 0s - loss: 48.4789 - 26ms/epoch - 2ms/step
# Epoch 149/1500
# 11/11 - 0s - loss: 48.5364 - 17ms/epoch - 2ms/step
# Epoch 150/1500
# 11/11 - 0s - loss: 48.2521 - 16ms/epoch - 1ms/step
# Epoch 151/1500
# 11/11 - 0s - loss: 48.3699 - 16ms/epoch - 1ms/step
# Epoch 152/1500
# 11/11 - 0s - loss: 48.4211 - 17ms/epoch - 2ms/step
# Epoch 153/1500
# 11/11 - 0s - loss: 47.7885 - 20ms/epoch - 2ms/step
# Epoch 154/1500
# 11/11 - 0s - loss: 47.5999 - 15ms/epoch - 1ms/step
# Epoch 155/1500
# 11/11 - 0s - loss: 47.4238 - 16ms/epoch - 1ms/step
# Epoch 156/1500
# 11/11 - 0s - loss: 47.2721 - 16ms/epoch - 1ms/step
# Epoch 157/1500
# 11/11 - 0s - loss: 47.0061 - 18ms/epoch - 2ms/step
# Epoch 158/1500
# 11/11 - 0s - loss: 46.9815 - 17ms/epoch - 2ms/step
# Epoch 159/1500
# 11/11 - 0s - loss: 46.7945 - 16ms/epoch - 1ms/step
# Epoch 160/1500
# 11/11 - 0s - loss: 47.5033 - 15ms/epoch - 1ms/step
# Epoch 161/1500
# 11/11 - 0s - loss: 47.1194 - 15ms/epoch - 1ms/step
# Epoch 162/1500
# 11/11 - 0s - loss: 46.9853 - 15ms/epoch - 1ms/step
# Epoch 163/1500
# 11/11 - 0s - loss: 46.0641 - 15ms/epoch - 1ms/step
# Epoch 164/1500
# 11/11 - 0s - loss: 46.1249 - 20ms/epoch - 2ms/step
# Epoch 165/1500
# 11/11 - 0s - loss: 45.8412 - 17ms/epoch - 2ms/step
# Epoch 166/1500
# 11/11 - 0s - loss: 45.5556 - 16ms/epoch - 1ms/step
# Epoch 167/1500
# 11/11 - 0s - loss: 45.7954 - 27ms/epoch - 2ms/step
# Epoch 168/1500
# 11/11 - 0s - loss: 45.6427 - 15ms/epoch - 1ms/step
# Epoch 169/1500
# 11/11 - 0s - loss: 45.3861 - 15ms/epoch - 1ms/step
# Epoch 170/1500
# 11/11 - 0s - loss: 45.1221 - 14ms/epoch - 1ms/step
# Epoch 171/1500
# 11/11 - 0s - loss: 45.2197 - 16ms/epoch - 1ms/step
# Epoch 172/1500
# 11/11 - 0s - loss: 45.4245 - 14ms/epoch - 1ms/step
# Epoch 173/1500
# 11/11 - 0s - loss: 44.5137 - 15ms/epoch - 1ms/step
# Epoch 174/1500
# 11/11 - 0s - loss: 44.2953 - 23ms/epoch - 2ms/step
# Epoch 175/1500
# 11/11 - 0s - loss: 44.6277 - 15ms/epoch - 1ms/step
# Epoch 176/1500
# 11/11 - 0s - loss: 44.3687 - 15ms/epoch - 1ms/step
# Epoch 177/1500
# 11/11 - 0s - loss: 43.9170 - 15ms/epoch - 1ms/step
# Epoch 178/1500
# 11/11 - 0s - loss: 43.4026 - 14ms/epoch - 1ms/step
# Epoch 179/1500
# 11/11 - 0s - loss: 43.9146 - 14ms/epoch - 1ms/step
# Epoch 180/1500
# 11/11 - 0s - loss: 44.3598 - 14ms/epoch - 1ms/step
# Epoch 181/1500
# 11/11 - 0s - loss: 43.7682 - 13ms/epoch - 1ms/step
# Epoch 182/1500
# 11/11 - 0s - loss: 43.0349 - 13ms/epoch - 1ms/step
# Epoch 183/1500
# 11/11 - 0s - loss: 42.7961 - 18ms/epoch - 2ms/step
# Epoch 184/1500
# 11/11 - 0s - loss: 43.3468 - 15ms/epoch - 1ms/step
# Epoch 185/1500
# 11/11 - 0s - loss: 42.8670 - 19ms/epoch - 2ms/step
# Epoch 186/1500
# 11/11 - 0s - loss: 42.6351 - 16ms/epoch - 1ms/step
# Epoch 187/1500
# 11/11 - 0s - loss: 42.9640 - 15ms/epoch - 1ms/step
# Epoch 188/1500
# 11/11 - 0s - loss: 42.5904 - 13ms/epoch - 1ms/step
# Epoch 189/1500
# 11/11 - 0s - loss: 41.7751 - 13ms/epoch - 1ms/step
# Epoch 190/1500
# 11/11 - 0s - loss: 41.5707 - 13ms/epoch - 1ms/step
# Epoch 191/1500
# 11/11 - 0s - loss: 41.6862 - 15ms/epoch - 1ms/step
# Epoch 192/1500
# 11/11 - 0s - loss: 41.4377 - 13ms/epoch - 1ms/step
# Epoch 193/1500
# 11/11 - 0s - loss: 41.0171 - 14ms/epoch - 1ms/step
# Epoch 194/1500
# 11/11 - 0s - loss: 40.9658 - 16ms/epoch - 1ms/step
# Epoch 195/1500
# 11/11 - 0s - loss: 40.7254 - 18ms/epoch - 2ms/step
# Epoch 196/1500
# 11/11 - 0s - loss: 40.7767 - 16ms/epoch - 1ms/step
# Epoch 197/1500
# 11/11 - 0s - loss: 40.5330 - 18ms/epoch - 2ms/step
# Epoch 198/1500
# 11/11 - 0s - loss: 40.3201 - 14ms/epoch - 1ms/step
# Epoch 199/1500
# 11/11 - 0s - loss: 39.8367 - 17ms/epoch - 2ms/step
# Epoch 200/1500
# 11/11 - 0s - loss: 39.7346 - 14ms/epoch - 1ms/step
# Epoch 201/1500
# 11/11 - 0s - loss: 39.3465 - 15ms/epoch - 1ms/step
# Epoch 202/1500
# 11/11 - 0s - loss: 39.0964 - 15ms/epoch - 1ms/step
# Epoch 203/1500
# 11/11 - 0s - loss: 39.3979 - 15ms/epoch - 1ms/step
# Epoch 204/1500
# 11/11 - 0s - loss: 39.3966 - 15ms/epoch - 1ms/step
# Epoch 205/1500
# 11/11 - 0s - loss: 40.4636 - 15ms/epoch - 1ms/step
# Epoch 206/1500
# 11/11 - 0s - loss: 40.9227 - 15ms/epoch - 1ms/step
# Epoch 207/1500
# 11/11 - 0s - loss: 38.5657 - 14ms/epoch - 1ms/step
# Epoch 208/1500
# 11/11 - 0s - loss: 38.5323 - 16ms/epoch - 1ms/step
# Epoch 209/1500
# 11/11 - 0s - loss: 38.3928 - 15ms/epoch - 1ms/step
# Epoch 210/1500
# 11/11 - 0s - loss: 37.6786 - 13ms/epoch - 1ms/step
# Epoch 211/1500
# 11/11 - 0s - loss: 37.6848 - 15ms/epoch - 1ms/step
# Epoch 212/1500
# 11/11 - 0s - loss: 37.9747 - 14ms/epoch - 1ms/step
# Epoch 213/1500
# 11/11 - 0s - loss: 37.3875 - 15ms/epoch - 1ms/step
# Epoch 214/1500
# 11/11 - 0s - loss: 37.0852 - 23ms/epoch - 2ms/step
# Epoch 215/1500
# 11/11 - 0s - loss: 36.8429 - 15ms/epoch - 1ms/step
# Epoch 216/1500
# 11/11 - 0s - loss: 36.9746 - 15ms/epoch - 1ms/step
# Epoch 217/1500
# 11/11 - 0s - loss: 36.5958 - 16ms/epoch - 1ms/step
# Epoch 218/1500
# 11/11 - 0s - loss: 36.9699 - 14ms/epoch - 1ms/step
# Epoch 219/1500
# 11/11 - 0s - loss: 37.0741 - 15ms/epoch - 1ms/step
# Epoch 220/1500
# 11/11 - 0s - loss: 36.9851 - 14ms/epoch - 1ms/step
# Epoch 221/1500
# 11/11 - 0s - loss: 36.7535 - 14ms/epoch - 1ms/step
# Epoch 222/1500
# 11/11 - 0s - loss: 36.2124 - 14ms/epoch - 1ms/step
# Epoch 223/1500
# 11/11 - 0s - loss: 36.1429 - 14ms/epoch - 1ms/step
# Epoch 224/1500
# 11/11 - 0s - loss: 36.5018 - 12ms/epoch - 1ms/step
# Epoch 225/1500
# 11/11 - 0s - loss: 36.1521 - 15ms/epoch - 1ms/step
# Epoch 226/1500
# 11/11 - 0s - loss: 35.2315 - 14ms/epoch - 1ms/step
# Epoch 227/1500
# 11/11 - 0s - loss: 36.1754 - 16ms/epoch - 1ms/step
# Epoch 228/1500
# 11/11 - 0s - loss: 35.1417 - 20ms/epoch - 2ms/step
# Epoch 229/1500
# 11/11 - 0s - loss: 35.2089 - 22ms/epoch - 2ms/step
# Epoch 230/1500
# 11/11 - 0s - loss: 34.7822 - 13ms/epoch - 1ms/step
# Epoch 231/1500
# 11/11 - 0s - loss: 34.5854 - 13ms/epoch - 1ms/step
# Epoch 232/1500
# 11/11 - 0s - loss: 35.1369 - 13ms/epoch - 1ms/step
# Epoch 233/1500
# 11/11 - 0s - loss: 34.4094 - 17ms/epoch - 2ms/step
# Epoch 234/1500
# 11/11 - 0s - loss: 34.3103 - 14ms/epoch - 1ms/step
# Epoch 235/1500
# 11/11 - 0s - loss: 34.0985 - 13ms/epoch - 1ms/step
# Epoch 236/1500
# 11/11 - 0s - loss: 34.0120 - 14ms/epoch - 1ms/step
# Epoch 237/1500
# 11/11 - 0s - loss: 33.9625 - 15ms/epoch - 1ms/step
# Epoch 238/1500
# 11/11 - 0s - loss: 33.6253 - 14ms/epoch - 1ms/step
# Epoch 239/1500
# 11/11 - 0s - loss: 33.5665 - 13ms/epoch - 1ms/step
# Epoch 240/1500
# 11/11 - 0s - loss: 33.3819 - 15ms/epoch - 1ms/step
# Epoch 241/1500
# 11/11 - 0s - loss: 33.3461 - 13ms/epoch - 1ms/step
# Epoch 242/1500
# 11/11 - 0s - loss: 33.1487 - 15ms/epoch - 1ms/step
# Epoch 243/1500
# 11/11 - 0s - loss: 33.8191 - 15ms/epoch - 1ms/step
# Epoch 244/1500
# 11/11 - 0s - loss: 33.0781 - 24ms/epoch - 2ms/step
# Epoch 245/1500
# 11/11 - 0s - loss: 32.8868 - 13ms/epoch - 1ms/step
# Epoch 246/1500
# 11/11 - 0s - loss: 32.6736 - 14ms/epoch - 1ms/step
# Epoch 247/1500
# 11/11 - 0s - loss: 32.6721 - 14ms/epoch - 1ms/step
# Epoch 248/1500
# 11/11 - 0s - loss: 32.7642 - 14ms/epoch - 1ms/step
# Epoch 249/1500
# 11/11 - 0s - loss: 32.6728 - 14ms/epoch - 1ms/step
# Epoch 250/1500
# 11/11 - 0s - loss: 32.6475 - 17ms/epoch - 2ms/step
# Epoch 251/1500
# 11/11 - 0s - loss: 32.3047 - 14ms/epoch - 1ms/step
# Epoch 252/1500
# 11/11 - 0s - loss: 32.0532 - 13ms/epoch - 1ms/step
# Epoch 253/1500
# 11/11 - 0s - loss: 32.2759 - 15ms/epoch - 1ms/step
# Epoch 254/1500
# 11/11 - 0s - loss: 31.9932 - 15ms/epoch - 1ms/step
# Epoch 255/1500
# 11/11 - 0s - loss: 32.2855 - 13ms/epoch - 1ms/step
# Epoch 256/1500
# 11/11 - 0s - loss: 31.6792 - 14ms/epoch - 1ms/step
# Epoch 257/1500
# 11/11 - 0s - loss: 32.0722 - 13ms/epoch - 1ms/step
# Epoch 258/1500
# 11/11 - 0s - loss: 32.0839 - 14ms/epoch - 1ms/step
# Epoch 259/1500
# 11/11 - 0s - loss: 32.4109 - 13ms/epoch - 1ms/step
# Epoch 260/1500
# 11/11 - 0s - loss: 31.2902 - 14ms/epoch - 1ms/step
# Epoch 261/1500
# 11/11 - 0s - loss: 31.3308 - 16ms/epoch - 1ms/step
# Epoch 262/1500
# 11/11 - 0s - loss: 31.4391 - 14ms/epoch - 1ms/step
# Epoch 263/1500
# 11/11 - 0s - loss: 30.8423 - 13ms/epoch - 1ms/step
# Epoch 264/1500
# 11/11 - 0s - loss: 31.1602 - 13ms/epoch - 1ms/step
# Epoch 265/1500
# 11/11 - 0s - loss: 30.7613 - 16ms/epoch - 1ms/step
# Epoch 266/1500
# 11/11 - 0s - loss: 30.7324 - 15ms/epoch - 1ms/step
# Epoch 267/1500
# 11/11 - 0s - loss: 30.5014 - 14ms/epoch - 1ms/step
# Epoch 268/1500
# 11/11 - 0s - loss: 30.9590 - 16ms/epoch - 1ms/step
# Epoch 269/1500
# 11/11 - 0s - loss: 30.2796 - 15ms/epoch - 1ms/step
# Epoch 270/1500
# 11/11 - 0s - loss: 30.1807 - 14ms/epoch - 1ms/step
# Epoch 271/1500
# 11/11 - 0s - loss: 30.7147 - 19ms/epoch - 2ms/step
# Epoch 272/1500
# 11/11 - 0s - loss: 30.8220 - 14ms/epoch - 1ms/step
# Epoch 273/1500
# 11/11 - 0s - loss: 30.1800 - 16ms/epoch - 1ms/step
# Epoch 274/1500
# 11/11 - 0s - loss: 30.3082 - 14ms/epoch - 1ms/step
# Epoch 275/1500
# 11/11 - 0s - loss: 30.2373 - 17ms/epoch - 2ms/step
# Epoch 276/1500
# 11/11 - 0s - loss: 30.1678 - 15ms/epoch - 1ms/step
# Epoch 277/1500
# 11/11 - 0s - loss: 30.1301 - 25ms/epoch - 2ms/step
# Epoch 278/1500
# 11/11 - 0s - loss: 30.5080 - 14ms/epoch - 1ms/step
# Epoch 279/1500
# 11/11 - 0s - loss: 29.9987 - 16ms/epoch - 1ms/step
# Epoch 280/1500
# 11/11 - 0s - loss: 29.5798 - 18ms/epoch - 2ms/step
# Epoch 281/1500
# 11/11 - 0s - loss: 29.5349 - 13ms/epoch - 1ms/step
# Epoch 282/1500
# 11/11 - 0s - loss: 29.5794 - 13ms/epoch - 1ms/step
# Epoch 283/1500
# 11/11 - 0s - loss: 29.6690 - 14ms/epoch - 1ms/step
# Epoch 284/1500
# 11/11 - 0s - loss: 29.1591 - 15ms/epoch - 1ms/step
# Epoch 285/1500
# 11/11 - 0s - loss: 31.7518 - 18ms/epoch - 2ms/step
# Epoch 286/1500
# 11/11 - 0s - loss: 31.5874 - 20ms/epoch - 2ms/step
# Epoch 287/1500
# 11/11 - 0s - loss: 30.0131 - 13ms/epoch - 1ms/step
# Epoch 288/1500
# 11/11 - 0s - loss: 28.6855 - 16ms/epoch - 1ms/step
# Epoch 289/1500
# 11/11 - 0s - loss: 29.3596 - 17ms/epoch - 2ms/step
# Epoch 290/1500
# 11/11 - 0s - loss: 29.1312 - 16ms/epoch - 1ms/step
# Epoch 291/1500
# 11/11 - 0s - loss: 29.1551 - 17ms/epoch - 2ms/step
# Epoch 292/1500
# 11/11 - 0s - loss: 30.3911 - 13ms/epoch - 1ms/step
# Epoch 293/1500
# 11/11 - 0s - loss: 29.8646 - 19ms/epoch - 2ms/step
# Epoch 294/1500
# 11/11 - 0s - loss: 28.6693 - 18ms/epoch - 2ms/step
# Epoch 295/1500
# 11/11 - 0s - loss: 30.3176 - 19ms/epoch - 2ms/step
# Epoch 296/1500
# 11/11 - 0s - loss: 29.2558 - 17ms/epoch - 2ms/step
# Epoch 297/1500
# 11/11 - 0s - loss: 29.3478 - 16ms/epoch - 1ms/step
# Epoch 298/1500
# 11/11 - 0s - loss: 28.6524 - 14ms/epoch - 1ms/step
# Epoch 299/1500
# 11/11 - 0s - loss: 29.3608 - 15ms/epoch - 1ms/step
# Epoch 300/1500
# 11/11 - 0s - loss: 28.7064 - 15ms/epoch - 1ms/step
# Epoch 301/1500
# 11/11 - 0s - loss: 28.5841 - 16ms/epoch - 1ms/step
# Epoch 302/1500
# 11/11 - 0s - loss: 29.3075 - 15ms/epoch - 1ms/step
# Epoch 303/1500
# 11/11 - 0s - loss: 30.0089 - 17ms/epoch - 2ms/step
# Epoch 304/1500
# 11/11 - 0s - loss: 29.8958 - 15ms/epoch - 1ms/step
# Epoch 305/1500
# 11/11 - 0s - loss: 29.5959 - 15ms/epoch - 1ms/step
# Epoch 306/1500
# 11/11 - 0s - loss: 28.5528 - 17ms/epoch - 2ms/step
# Epoch 307/1500
# 11/11 - 0s - loss: 28.2687 - 24ms/epoch - 2ms/step
# Epoch 308/1500
# 11/11 - 0s - loss: 28.1944 - 17ms/epoch - 2ms/step
# Epoch 309/1500
# 11/11 - 0s - loss: 28.4491 - 14ms/epoch - 1ms/step
# Epoch 310/1500
# 11/11 - 0s - loss: 28.2102 - 16ms/epoch - 1ms/step
# Epoch 311/1500
# 11/11 - 0s - loss: 27.9608 - 16ms/epoch - 1ms/step
# Epoch 312/1500
# 11/11 - 0s - loss: 27.9394 - 16ms/epoch - 1ms/step
# Epoch 313/1500
# 11/11 - 0s - loss: 29.5340 - 15ms/epoch - 1ms/step
# Epoch 314/1500
# 11/11 - 0s - loss: 28.3383 - 18ms/epoch - 2ms/step
# Epoch 315/1500
# 11/11 - 0s - loss: 28.1564 - 13ms/epoch - 1ms/step
# Epoch 316/1500
# 11/11 - 0s - loss: 27.4179 - 17ms/epoch - 2ms/step
# Epoch 317/1500
# 11/11 - 0s - loss: 27.7194 - 16ms/epoch - 1ms/step
# Epoch 318/1500
# 11/11 - 0s - loss: 27.3594 - 17ms/epoch - 2ms/step
# Epoch 319/1500
# 11/11 - 0s - loss: 27.6527 - 17ms/epoch - 2ms/step
# Epoch 320/1500
# 11/11 - 0s - loss: 27.4546 - 15ms/epoch - 1ms/step
# Epoch 321/1500
# 11/11 - 0s - loss: 27.6255 - 18ms/epoch - 2ms/step
# Epoch 322/1500
# 11/11 - 0s - loss: 27.4629 - 20ms/epoch - 2ms/step
# Epoch 323/1500
# 11/11 - 0s - loss: 27.7989 - 17ms/epoch - 2ms/step
# Epoch 324/1500
# 11/11 - 0s - loss: 27.0270 - 15ms/epoch - 1ms/step
# Epoch 325/1500
# 11/11 - 0s - loss: 29.1917 - 17ms/epoch - 2ms/step
# Epoch 326/1500
# 11/11 - 0s - loss: 27.9870 - 14ms/epoch - 1ms/step
# Epoch 327/1500
# 11/11 - 0s - loss: 28.1743 - 15ms/epoch - 1ms/step
# Epoch 328/1500
# 11/11 - 0s - loss: 27.1920 - 14ms/epoch - 1ms/step
# Epoch 329/1500
# 11/11 - 0s - loss: 27.1018 - 17ms/epoch - 2ms/step
# Epoch 330/1500
# 11/11 - 0s - loss: 27.3879 - 18ms/epoch - 2ms/step
# Epoch 331/1500
# 11/11 - 0s - loss: 27.2920 - 15ms/epoch - 1ms/step
# Epoch 332/1500
# 11/11 - 0s - loss: 26.8383 - 15ms/epoch - 1ms/step
# Epoch 333/1500
# 11/11 - 0s - loss: 27.1377 - 17ms/epoch - 2ms/step
# Epoch 334/1500
# 11/11 - 0s - loss: 27.5733 - 19ms/epoch - 2ms/step
# Epoch 335/1500
# 11/11 - 0s - loss: 26.7045 - 16ms/epoch - 1ms/step
# Epoch 336/1500
# 11/11 - 0s - loss: 26.9455 - 18ms/epoch - 2ms/step
# Epoch 337/1500
# 11/11 - 0s - loss: 27.3593 - 31ms/epoch - 3ms/step
# Epoch 338/1500
# 11/11 - 0s - loss: 27.3887 - 14ms/epoch - 1ms/step
# Epoch 339/1500
# 11/11 - 0s - loss: 30.3574 - 14ms/epoch - 1ms/step
# Epoch 340/1500
# 11/11 - 0s - loss: 28.9195 - 15ms/epoch - 1ms/step
# Epoch 341/1500
# 11/11 - 0s - loss: 26.7231 - 15ms/epoch - 1ms/step
# Epoch 342/1500
# 11/11 - 0s - loss: 28.3252 - 19ms/epoch - 2ms/step
# Epoch 343/1500
# 11/11 - 0s - loss: 26.9725 - 14ms/epoch - 1ms/step
# Epoch 344/1500
# 11/11 - 0s - loss: 27.0205 - 15ms/epoch - 1ms/step
# Epoch 345/1500
# 11/11 - 0s - loss: 27.0311 - 16ms/epoch - 1ms/step
# Epoch 346/1500
# 11/11 - 0s - loss: 27.1534 - 16ms/epoch - 1ms/step
# Epoch 347/1500
# 11/11 - 0s - loss: 26.5536 - 17ms/epoch - 2ms/step
# Epoch 348/1500
# 11/11 - 0s - loss: 27.4010 - 18ms/epoch - 2ms/step
# Epoch 349/1500
# 11/11 - 0s - loss: 27.5899 - 20ms/epoch - 2ms/step
# Epoch 350/1500
# 11/11 - 0s - loss: 27.4726 - 16ms/epoch - 1ms/step
# Epoch 351/1500
# 11/11 - 0s - loss: 26.2770 - 17ms/epoch - 2ms/step
# Epoch 352/1500
# 11/11 - 0s - loss: 26.8137 - 16ms/epoch - 1ms/step
# Epoch 353/1500
# 11/11 - 0s - loss: 26.2580 - 14ms/epoch - 1ms/step
# Epoch 354/1500
# 11/11 - 0s - loss: 26.5168 - 13ms/epoch - 1ms/step
# Epoch 355/1500
# 11/11 - 0s - loss: 26.3737 - 13ms/epoch - 1ms/step
# Epoch 356/1500
# 11/11 - 0s - loss: 26.2465 - 12ms/epoch - 1ms/step
# Epoch 357/1500
# 11/11 - 0s - loss: 26.5167 - 12ms/epoch - 1ms/step
# Epoch 358/1500
# 11/11 - 0s - loss: 26.9162 - 13ms/epoch - 1ms/step
# Epoch 359/1500
# 11/11 - 0s - loss: 26.1174 - 13ms/epoch - 1ms/step
# Epoch 360/1500
# 11/11 - 0s - loss: 26.0993 - 13ms/epoch - 1ms/step
# Epoch 361/1500
# 11/11 - 0s - loss: 26.2103 - 13ms/epoch - 1ms/step
# Epoch 362/1500
# 11/11 - 0s - loss: 26.2655 - 15ms/epoch - 1ms/step
# Epoch 363/1500
# 11/11 - 0s - loss: 26.2514 - 16ms/epoch - 1ms/step
# Epoch 364/1500
# 11/11 - 0s - loss: 26.9272 - 15ms/epoch - 1ms/step
# Epoch 365/1500
# 11/11 - 0s - loss: 26.3735 - 13ms/epoch - 1ms/step
# Epoch 366/1500
# 11/11 - 0s - loss: 26.4735 - 18ms/epoch - 2ms/step
# Epoch 367/1500
# 11/11 - 0s - loss: 26.8648 - 14ms/epoch - 1ms/step
# Epoch 368/1500
# 11/11 - 0s - loss: 26.4521 - 15ms/epoch - 1ms/step
# Epoch 369/1500
# 11/11 - 0s - loss: 26.4443 - 17ms/epoch - 2ms/step
# Epoch 370/1500
# 11/11 - 0s - loss: 26.2792 - 15ms/epoch - 1ms/step
# Epoch 371/1500
# 11/11 - 0s - loss: 25.7369 - 13ms/epoch - 1ms/step
# Epoch 372/1500
# 11/11 - 0s - loss: 25.7409 - 15ms/epoch - 1ms/step
# Epoch 373/1500
# 11/11 - 0s - loss: 26.8903 - 15ms/epoch - 1ms/step
# Epoch 374/1500
# 11/11 - 0s - loss: 26.0616 - 15ms/epoch - 1ms/step
# Epoch 375/1500
# 11/11 - 0s - loss: 25.9959 - 16ms/epoch - 1ms/step
# Epoch 376/1500
# 11/11 - 0s - loss: 25.7085 - 14ms/epoch - 1ms/step
# Epoch 377/1500
# 11/11 - 0s - loss: 26.0065 - 16ms/epoch - 1ms/step
# Epoch 378/1500
# 11/11 - 0s - loss: 26.7126 - 14ms/epoch - 1ms/step
# Epoch 379/1500
# 11/11 - 0s - loss: 25.6888 - 13ms/epoch - 1ms/step
# Epoch 380/1500
# 11/11 - 0s - loss: 25.6433 - 14ms/epoch - 1ms/step
# Epoch 381/1500
# 11/11 - 0s - loss: 26.9864 - 12ms/epoch - 1ms/step
# Epoch 382/1500
# 11/11 - 0s - loss: 25.9679 - 14ms/epoch - 1ms/step
# Epoch 383/1500
# 11/11 - 0s - loss: 25.7486 - 16ms/epoch - 1ms/step
# Epoch 384/1500
# 11/11 - 0s - loss: 25.9730 - 20ms/epoch - 2ms/step
# Epoch 385/1500
# 11/11 - 0s - loss: 25.5225 - 16ms/epoch - 1ms/step
# Epoch 386/1500
# 11/11 - 0s - loss: 25.9693 - 15ms/epoch - 1ms/step
# Epoch 387/1500
# 11/11 - 0s - loss: 25.6401 - 13ms/epoch - 1ms/step
# Epoch 388/1500
# 11/11 - 0s - loss: 26.0869 - 13ms/epoch - 1ms/step
# Epoch 389/1500
# 11/11 - 0s - loss: 26.1275 - 13ms/epoch - 1ms/step
# Epoch 390/1500
# 11/11 - 0s - loss: 25.6086 - 18ms/epoch - 2ms/step
# Epoch 391/1500
# 11/11 - 0s - loss: 25.5475 - 16ms/epoch - 1ms/step
# Epoch 392/1500
# 11/11 - 0s - loss: 25.9591 - 19ms/epoch - 2ms/step
# Epoch 393/1500
# 11/11 - 0s - loss: 28.4176 - 15ms/epoch - 1ms/step
# Epoch 394/1500
# 11/11 - 0s - loss: 26.0555 - 16ms/epoch - 1ms/step
# Epoch 395/1500
# 11/11 - 0s - loss: 25.3855 - 14ms/epoch - 1ms/step
# Epoch 396/1500
# 11/11 - 0s - loss: 25.6749 - 14ms/epoch - 1ms/step
# Epoch 397/1500
# 11/11 - 0s - loss: 25.2583 - 13ms/epoch - 1ms/step
# Epoch 398/1500
# 11/11 - 0s - loss: 26.1311 - 18ms/epoch - 2ms/step
# Epoch 399/1500
# 11/11 - 0s - loss: 26.6946 - 13ms/epoch - 1ms/step
# Epoch 400/1500
# 11/11 - 0s - loss: 26.2176 - 14ms/epoch - 1ms/step
# Epoch 401/1500
# 11/11 - 0s - loss: 27.3479 - 15ms/epoch - 1ms/step
# Epoch 402/1500
# 11/11 - 0s - loss: 26.0487 - 18ms/epoch - 2ms/step
# Epoch 403/1500
# 11/11 - 0s - loss: 26.0092 - 14ms/epoch - 1ms/step
# Epoch 404/1500
# 11/11 - 0s - loss: 25.2431 - 15ms/epoch - 1ms/step
# Epoch 405/1500
# 11/11 - 0s - loss: 24.8955 - 13ms/epoch - 1ms/step
# Epoch 406/1500
# 11/11 - 0s - loss: 25.5817 - 13ms/epoch - 1ms/step
# Epoch 407/1500
# 11/11 - 0s - loss: 26.4504 - 13ms/epoch - 1ms/step
# Epoch 408/1500
# 11/11 - 0s - loss: 25.2199 - 12ms/epoch - 1ms/step
# Epoch 409/1500
# 11/11 - 0s - loss: 25.3610 - 13ms/epoch - 1ms/step
# Epoch 410/1500
# 11/11 - 0s - loss: 25.4247 - 21ms/epoch - 2ms/step
# Epoch 411/1500
# 11/11 - 0s - loss: 25.7545 - 19ms/epoch - 2ms/step
# Epoch 412/1500
# 11/11 - 0s - loss: 24.9185 - 14ms/epoch - 1ms/step
# Epoch 413/1500
# 11/11 - 0s - loss: 25.2878 - 15ms/epoch - 1ms/step
# Epoch 414/1500
# 11/11 - 0s - loss: 25.1853 - 12ms/epoch - 1ms/step
# Epoch 415/1500
# 11/11 - 0s - loss: 26.6486 - 15ms/epoch - 1ms/step
# Epoch 416/1500
# 11/11 - 0s - loss: 26.1422 - 15ms/epoch - 1ms/step
# Epoch 417/1500
# 11/11 - 0s - loss: 24.8120 - 16ms/epoch - 1ms/step
# Epoch 418/1500
# 11/11 - 0s - loss: 24.9711 - 15ms/epoch - 1ms/step
# Epoch 419/1500
# 11/11 - 0s - loss: 25.4217 - 16ms/epoch - 1ms/step
# Epoch 420/1500
# 11/11 - 0s - loss: 25.0856 - 16ms/epoch - 1ms/step
# Epoch 421/1500
# 11/11 - 0s - loss: 24.6810 - 16ms/epoch - 1ms/step
# Epoch 422/1500
# 11/11 - 0s - loss: 25.0262 - 18ms/epoch - 2ms/step
# Epoch 423/1500
# 11/11 - 0s - loss: 26.8432 - 16ms/epoch - 1ms/step
# Epoch 424/1500
# 11/11 - 0s - loss: 26.9132 - 16ms/epoch - 1ms/step
# Epoch 425/1500
# 11/11 - 0s - loss: 26.3696 - 14ms/epoch - 1ms/step
# Epoch 426/1500
# 11/11 - 0s - loss: 25.2241 - 16ms/epoch - 1ms/step
# Epoch 427/1500
# 11/11 - 0s - loss: 26.8177 - 16ms/epoch - 1ms/step
# Epoch 428/1500
# 11/11 - 0s - loss: 25.7078 - 24ms/epoch - 2ms/step
# Epoch 429/1500
# 11/11 - 0s - loss: 25.9972 - 19ms/epoch - 2ms/step
# Epoch 430/1500
# 11/11 - 0s - loss: 29.3872 - 19ms/epoch - 2ms/step
# Epoch 431/1500
# 11/11 - 0s - loss: 25.2010 - 18ms/epoch - 2ms/step
# Epoch 432/1500
# 11/11 - 0s - loss: 25.3550 - 18ms/epoch - 2ms/step
# Epoch 433/1500
# 11/11 - 0s - loss: 25.1953 - 18ms/epoch - 2ms/step
# Epoch 434/1500
# 11/11 - 0s - loss: 24.5534 - 16ms/epoch - 1ms/step
# Epoch 435/1500
# 11/11 - 0s - loss: 24.8817 - 16ms/epoch - 1ms/step
# Epoch 436/1500
# 11/11 - 0s - loss: 24.5924 - 17ms/epoch - 2ms/step
# Epoch 437/1500
# 11/11 - 0s - loss: 24.4417 - 17ms/epoch - 2ms/step
# Epoch 438/1500
# 11/11 - 0s - loss: 25.5617 - 18ms/epoch - 2ms/step
# Epoch 439/1500
# 11/11 - 0s - loss: 25.4777 - 17ms/epoch - 2ms/step
# Epoch 440/1500
# 11/11 - 0s - loss: 24.7633 - 16ms/epoch - 1ms/step
# Epoch 441/1500
# 11/11 - 0s - loss: 25.5143 - 17ms/epoch - 2ms/step
# Epoch 442/1500
# 11/11 - 0s - loss: 24.3690 - 20ms/epoch - 2ms/step
# Epoch 443/1500
# 11/11 - 0s - loss: 24.8169 - 18ms/epoch - 2ms/step
# Epoch 444/1500
# 11/11 - 0s - loss: 24.8563 - 19ms/epoch - 2ms/step
# Epoch 445/1500
# 11/11 - 0s - loss: 24.2439 - 18ms/epoch - 2ms/step
# Epoch 446/1500
# 11/11 - 0s - loss: 24.6288 - 17ms/epoch - 2ms/step
# Epoch 447/1500
# 11/11 - 0s - loss: 24.3222 - 16ms/epoch - 1ms/step
# Epoch 448/1500
# 11/11 - 0s - loss: 25.0509 - 17ms/epoch - 2ms/step
# Epoch 449/1500
# 11/11 - 0s - loss: 24.5132 - 21ms/epoch - 2ms/step
# Epoch 450/1500
# 11/11 - 0s - loss: 25.5683 - 20ms/epoch - 2ms/step
# Epoch 451/1500
# 11/11 - 0s - loss: 24.2170 - 16ms/epoch - 1ms/step
# Epoch 452/1500
# 11/11 - 0s - loss: 24.4705 - 16ms/epoch - 1ms/step
# Epoch 453/1500
# 11/11 - 0s - loss: 24.2969 - 15ms/epoch - 1ms/step
# Epoch 454/1500
# 11/11 - 0s - loss: 24.6265 - 14ms/epoch - 1ms/step
# Epoch 455/1500
# 11/11 - 0s - loss: 25.2449 - 15ms/epoch - 1ms/step
# Epoch 456/1500
# 11/11 - 0s - loss: 25.2956 - 17ms/epoch - 2ms/step
# Epoch 457/1500
# 11/11 - 0s - loss: 25.1878 - 16ms/epoch - 1ms/step
# Epoch 458/1500
# 11/11 - 0s - loss: 24.8225 - 15ms/epoch - 1ms/step
# Epoch 459/1500
# 11/11 - 0s - loss: 24.2451 - 17ms/epoch - 2ms/step
# Epoch 460/1500
# 11/11 - 0s - loss: 24.3665 - 16ms/epoch - 1ms/step
# Epoch 461/1500
# 11/11 - 0s - loss: 23.8884 - 15ms/epoch - 1ms/step
# Epoch 462/1500
# 11/11 - 0s - loss: 23.9209 - 16ms/epoch - 1ms/step
# Epoch 463/1500
# 11/11 - 0s - loss: 24.1355 - 13ms/epoch - 1ms/step
# Epoch 464/1500
# 11/11 - 0s - loss: 24.2569 - 15ms/epoch - 1ms/step
# Epoch 465/1500
# 11/11 - 0s - loss: 24.9993 - 14ms/epoch - 1ms/step
# Epoch 466/1500
# 11/11 - 0s - loss: 24.4206 - 15ms/epoch - 1ms/step
# Epoch 467/1500
# 11/11 - 0s - loss: 24.5959 - 17ms/epoch - 2ms/step
# Epoch 468/1500
# 11/11 - 0s - loss: 23.8518 - 19ms/epoch - 2ms/step
# Epoch 469/1500
# 11/11 - 0s - loss: 23.6535 - 16ms/epoch - 1ms/step
# Epoch 470/1500
# 11/11 - 0s - loss: 24.2412 - 15ms/epoch - 1ms/step
# Epoch 471/1500
# 11/11 - 0s - loss: 24.3589 - 15ms/epoch - 1ms/step
# Epoch 472/1500
# 11/11 - 0s - loss: 24.4797 - 14ms/epoch - 1ms/step
# Epoch 473/1500
# 11/11 - 0s - loss: 23.8835 - 15ms/epoch - 1ms/step
# Epoch 474/1500
# 11/11 - 0s - loss: 25.1629 - 14ms/epoch - 1ms/step
# Epoch 475/1500
# 11/11 - 0s - loss: 24.0201 - 15ms/epoch - 1ms/step
# Epoch 476/1500
# 11/11 - 0s - loss: 24.8747 - 16ms/epoch - 1ms/step
# Epoch 477/1500
# 11/11 - 0s - loss: 23.2942 - 22ms/epoch - 2ms/step
# Epoch 478/1500
# 11/11 - 0s - loss: 23.4521 - 13ms/epoch - 1ms/step
# Epoch 479/1500
# 11/11 - 0s - loss: 23.7656 - 13ms/epoch - 1ms/step
# Epoch 480/1500
# 11/11 - 0s - loss: 23.5721 - 16ms/epoch - 1ms/step
# Epoch 481/1500
# 11/11 - 0s - loss: 24.5841 - 18ms/epoch - 2ms/step
# Epoch 482/1500
# 11/11 - 0s - loss: 23.3779 - 16ms/epoch - 1ms/step
# Epoch 483/1500
# 11/11 - 0s - loss: 24.0646 - 16ms/epoch - 1ms/step
# Epoch 484/1500
# 11/11 - 0s - loss: 23.1647 - 15ms/epoch - 1ms/step
# Epoch 485/1500
# 11/11 - 0s - loss: 23.6492 - 14ms/epoch - 1ms/step
# Epoch 486/1500
# 11/11 - 0s - loss: 23.0608 - 15ms/epoch - 1ms/step
# Epoch 487/1500
# 11/11 - 0s - loss: 23.5196 - 14ms/epoch - 1ms/step
# Epoch 488/1500
# 11/11 - 0s - loss: 23.7865 - 15ms/epoch - 1ms/step
# Epoch 489/1500
# 11/11 - 0s - loss: 23.4827 - 15ms/epoch - 1ms/step
# Epoch 490/1500
# 11/11 - 0s - loss: 23.4582 - 14ms/epoch - 1ms/step
# Epoch 491/1500
# 11/11 - 0s - loss: 24.9370 - 17ms/epoch - 2ms/step
# Epoch 492/1500
# 11/11 - 0s - loss: 24.3995 - 16ms/epoch - 1ms/step
# Epoch 493/1500
# 11/11 - 0s - loss: 24.7553 - 14ms/epoch - 1ms/step
# Epoch 494/1500
# 11/11 - 0s - loss: 23.2147 - 18ms/epoch - 2ms/step
# Epoch 495/1500
# 11/11 - 0s - loss: 25.6034 - 16ms/epoch - 1ms/step
# Epoch 496/1500
# 11/11 - 0s - loss: 24.4024 - 14ms/epoch - 1ms/step
# Epoch 497/1500
# 11/11 - 0s - loss: 23.2723 - 15ms/epoch - 1ms/step
# Epoch 498/1500
# 11/11 - 0s - loss: 24.0878 - 16ms/epoch - 1ms/step
# Epoch 499/1500
# 11/11 - 0s - loss: 24.0177 - 20ms/epoch - 2ms/step
# Epoch 500/1500
# 11/11 - 0s - loss: 23.8128 - 16ms/epoch - 1ms/step
# Epoch 501/1500
# 11/11 - 0s - loss: 22.8457 - 15ms/epoch - 1ms/step
# Epoch 502/1500
# 11/11 - 0s - loss: 23.2338 - 14ms/epoch - 1ms/step
# Epoch 503/1500
# 11/11 - 0s - loss: 22.9077 - 13ms/epoch - 1ms/step
# Epoch 504/1500
# 11/11 - 0s - loss: 23.3917 - 14ms/epoch - 1ms/step
# Epoch 505/1500
# 11/11 - 0s - loss: 24.3689 - 13ms/epoch - 1ms/step
# Epoch 506/1500
# 11/11 - 0s - loss: 24.6787 - 15ms/epoch - 1ms/step
# Epoch 507/1500
# 11/11 - 0s - loss: 22.7073 - 15ms/epoch - 1ms/step
# Epoch 508/1500
# 11/11 - 0s - loss: 23.6741 - 13ms/epoch - 1ms/step
# Epoch 509/1500
# 11/11 - 0s - loss: 23.8518 - 17ms/epoch - 2ms/step
# Epoch 510/1500
# 11/11 - 0s - loss: 23.5517 - 20ms/epoch - 2ms/step
# Epoch 511/1500
# 11/11 - 0s - loss: 23.7364 - 19ms/epoch - 2ms/step
# Epoch 512/1500
# 11/11 - 0s - loss: 24.1534 - 17ms/epoch - 2ms/step
# Epoch 513/1500
# 11/11 - 0s - loss: 24.5023 - 17ms/epoch - 2ms/step
# Epoch 514/1500
# 11/11 - 0s - loss: 23.2666 - 19ms/epoch - 2ms/step
# Epoch 515/1500
# 11/11 - 0s - loss: 24.0848 - 17ms/epoch - 2ms/step
# Epoch 516/1500
# 11/11 - 0s - loss: 23.9408 - 17ms/epoch - 2ms/step
# Epoch 517/1500
# 11/11 - 0s - loss: 25.1854 - 16ms/epoch - 1ms/step
# Epoch 518/1500
# 11/11 - 0s - loss: 23.3227 - 14ms/epoch - 1ms/step
# Epoch 519/1500
# 11/11 - 0s - loss: 22.5694 - 18ms/epoch - 2ms/step
# Epoch 520/1500
# 11/11 - 0s - loss: 22.4979 - 27ms/epoch - 2ms/step
# Epoch 521/1500
# 11/11 - 0s - loss: 22.7017 - 17ms/epoch - 2ms/step
# Epoch 522/1500
# 11/11 - 0s - loss: 22.5903 - 17ms/epoch - 2ms/step
# Epoch 523/1500
# 11/11 - 0s - loss: 22.6479 - 17ms/epoch - 2ms/step
# Epoch 524/1500
# 11/11 - 0s - loss: 22.8014 - 17ms/epoch - 2ms/step
# Epoch 525/1500
# 11/11 - 0s - loss: 22.3558 - 18ms/epoch - 2ms/step
# Epoch 526/1500
# 11/11 - 0s - loss: 22.9790 - 24ms/epoch - 2ms/step
# Epoch 527/1500
# 11/11 - 0s - loss: 22.7951 - 13ms/epoch - 1ms/step
# Epoch 528/1500
# 11/11 - 0s - loss: 22.1015 - 15ms/epoch - 1ms/step
# Epoch 529/1500
# 11/11 - 0s - loss: 22.9919 - 15ms/epoch - 1ms/step
# Epoch 530/1500
# 11/11 - 0s - loss: 22.7065 - 16ms/epoch - 1ms/step
# Epoch 531/1500
# 11/11 - 0s - loss: 22.8588 - 18ms/epoch - 2ms/step
# Epoch 532/1500
# 11/11 - 0s - loss: 23.5293 - 18ms/epoch - 2ms/step
# Epoch 533/1500
# 11/11 - 0s - loss: 23.3132 - 16ms/epoch - 1ms/step
# Epoch 534/1500
# 11/11 - 0s - loss: 22.6076 - 15ms/epoch - 1ms/step
# Epoch 535/1500
# 11/11 - 0s - loss: 22.3726 - 15ms/epoch - 1ms/step
# Epoch 536/1500
# 11/11 - 0s - loss: 22.1728 - 18ms/epoch - 2ms/step
# Epoch 537/1500
# 11/11 - 0s - loss: 22.5369 - 19ms/epoch - 2ms/step
# Epoch 538/1500
# 11/11 - 0s - loss: 22.1973 - 16ms/epoch - 1ms/step
# Epoch 539/1500
# 11/11 - 0s - loss: 22.4446 - 16ms/epoch - 1ms/step
# Epoch 540/1500
# 11/11 - 0s - loss: 23.5787 - 21ms/epoch - 2ms/step
# Epoch 541/1500
# 11/11 - 0s - loss: 22.6241 - 19ms/epoch - 2ms/step
# Epoch 542/1500
# 11/11 - 0s - loss: 22.7012 - 18ms/epoch - 2ms/step
# Epoch 543/1500
# 11/11 - 0s - loss: 22.2376 - 17ms/epoch - 2ms/step
# Epoch 544/1500
# 11/11 - 0s - loss: 22.2529 - 18ms/epoch - 2ms/step
# Epoch 545/1500
# 11/11 - 0s - loss: 22.9973 - 15ms/epoch - 1ms/step
# Epoch 546/1500
# 11/11 - 0s - loss: 23.0819 - 16ms/epoch - 1ms/step
# Epoch 547/1500
# 11/11 - 0s - loss: 23.1644 - 19ms/epoch - 2ms/step
# Epoch 548/1500
# 11/11 - 0s - loss: 24.1361 - 17ms/epoch - 2ms/step
# Epoch 549/1500
# 11/11 - 0s - loss: 22.0043 - 19ms/epoch - 2ms/step
# Epoch 550/1500
# 11/11 - 0s - loss: 22.0983 - 23ms/epoch - 2ms/step
# Epoch 551/1500
# 11/11 - 0s - loss: 21.8798 - 17ms/epoch - 2ms/step
# Epoch 552/1500
# 11/11 - 0s - loss: 22.2703 - 14ms/epoch - 1ms/step
# Epoch 553/1500
# 11/11 - 0s - loss: 22.3491 - 17ms/epoch - 2ms/step
# Epoch 554/1500
# 11/11 - 0s - loss: 26.2602 - 22ms/epoch - 2ms/step
# Epoch 555/1500
# 11/11 - 0s - loss: 21.7256 - 18ms/epoch - 2ms/step
# Epoch 556/1500
# 11/11 - 0s - loss: 22.4496 - 15ms/epoch - 1ms/step
# Epoch 557/1500
# 11/11 - 0s - loss: 22.0384 - 16ms/epoch - 1ms/step
# Epoch 558/1500
# 11/11 - 0s - loss: 21.9996 - 19ms/epoch - 2ms/step
# Epoch 559/1500
# 11/11 - 0s - loss: 21.8842 - 16ms/epoch - 1ms/step
# Epoch 560/1500
# 11/11 - 0s - loss: 22.4735 - 17ms/epoch - 2ms/step
# Epoch 561/1500
# 11/11 - 0s - loss: 24.4119 - 17ms/epoch - 2ms/step
# Epoch 562/1500
# 11/11 - 0s - loss: 22.9847 - 18ms/epoch - 2ms/step
# Epoch 563/1500
# 11/11 - 0s - loss: 23.6930 - 16ms/epoch - 1ms/step
# Epoch 564/1500
# 11/11 - 0s - loss: 22.0557 - 15ms/epoch - 1ms/step
# Epoch 565/1500
# 11/11 - 0s - loss: 21.5545 - 15ms/epoch - 1ms/step
# Epoch 566/1500
# 11/11 - 0s - loss: 21.9648 - 28ms/epoch - 3ms/step
# Epoch 567/1500
# 11/11 - 0s - loss: 24.1609 - 18ms/epoch - 2ms/step
# Epoch 568/1500
# 11/11 - 0s - loss: 22.1411 - 18ms/epoch - 2ms/step
# Epoch 569/1500
# 11/11 - 0s - loss: 21.8042 - 20ms/epoch - 2ms/step
# Epoch 570/1500
# 11/11 - 0s - loss: 23.6301 - 16ms/epoch - 1ms/step
# Epoch 571/1500
# 11/11 - 0s - loss: 22.2436 - 16ms/epoch - 1ms/step
# Epoch 572/1500
# 11/11 - 0s - loss: 21.6888 - 15ms/epoch - 1ms/step
# Epoch 573/1500
# 11/11 - 0s - loss: 22.6717 - 14ms/epoch - 1ms/step
# Epoch 574/1500
# 11/11 - 0s - loss: 22.9198 - 14ms/epoch - 1ms/step
# Epoch 575/1500
# 11/11 - 0s - loss: 21.5555 - 15ms/epoch - 1ms/step
# Epoch 576/1500
# 11/11 - 0s - loss: 22.1110 - 15ms/epoch - 1ms/step
# Epoch 577/1500
# 11/11 - 0s - loss: 22.9473 - 17ms/epoch - 2ms/step
# Epoch 578/1500
# 11/11 - 0s - loss: 21.6040 - 16ms/epoch - 1ms/step
# Epoch 579/1500
# 11/11 - 0s - loss: 21.2266 - 17ms/epoch - 2ms/step
# Epoch 580/1500
# 11/11 - 0s - loss: 21.3872 - 18ms/epoch - 2ms/step
# Epoch 581/1500
# 11/11 - 0s - loss: 22.1820 - 15ms/epoch - 1ms/step
# Epoch 582/1500
# 11/11 - 0s - loss: 21.8836 - 15ms/epoch - 1ms/step
# Epoch 583/1500
# 11/11 - 0s - loss: 21.4482 - 17ms/epoch - 2ms/step
# Epoch 584/1500
# 11/11 - 0s - loss: 21.8649 - 15ms/epoch - 1ms/step
# Epoch 585/1500
# 11/11 - 0s - loss: 22.3807 - 19ms/epoch - 2ms/step
# Epoch 586/1500
# 11/11 - 0s - loss: 21.6887 - 16ms/epoch - 1ms/step
# Epoch 587/1500
# 11/11 - 0s - loss: 21.3901 - 15ms/epoch - 1ms/step
# Epoch 588/1500
# 11/11 - 0s - loss: 21.6808 - 17ms/epoch - 2ms/step
# Epoch 589/1500
# 11/11 - 0s - loss: 21.3448 - 16ms/epoch - 1ms/step
# Epoch 590/1500
# 11/11 - 0s - loss: 21.4361 - 18ms/epoch - 2ms/step
# Epoch 591/1500
# 11/11 - 0s - loss: 22.5349 - 15ms/epoch - 1ms/step
# Epoch 592/1500
# 11/11 - 0s - loss: 21.9070 - 20ms/epoch - 2ms/step
# Epoch 593/1500
# 11/11 - 0s - loss: 20.7324 - 15ms/epoch - 1ms/step
# Epoch 594/1500
# 11/11 - 0s - loss: 22.5856 - 25ms/epoch - 2ms/step
# Epoch 595/1500
# 11/11 - 0s - loss: 26.2267 - 18ms/epoch - 2ms/step
# Epoch 596/1500
# 11/11 - 0s - loss: 21.7616 - 16ms/epoch - 1ms/step
# Epoch 597/1500
# 11/11 - 0s - loss: 21.1523 - 17ms/epoch - 2ms/step
# Epoch 598/1500
# 11/11 - 0s - loss: 21.0556 - 17ms/epoch - 2ms/step
# Epoch 599/1500
# 11/11 - 0s - loss: 21.0086 - 14ms/epoch - 1ms/step
# Epoch 600/1500
# 11/11 - 0s - loss: 21.3205 - 22ms/epoch - 2ms/step
# Epoch 601/1500
# 11/11 - 0s - loss: 22.4493 - 19ms/epoch - 2ms/step
# Epoch 602/1500
# 11/11 - 0s - loss: 21.9899 - 15ms/epoch - 1ms/step
# Epoch 603/1500
# 11/11 - 0s - loss: 21.4683 - 17ms/epoch - 2ms/step
# Epoch 604/1500
# 11/11 - 0s - loss: 21.0796 - 16ms/epoch - 1ms/step
# Epoch 605/1500
# 11/11 - 0s - loss: 21.2715 - 22ms/epoch - 2ms/step
# Epoch 606/1500
# 11/11 - 0s - loss: 21.4761 - 15ms/epoch - 1ms/step
# Epoch 607/1500
# 11/11 - 0s - loss: 22.3533 - 15ms/epoch - 1ms/step
# Epoch 608/1500
# 11/11 - 0s - loss: 22.6958 - 13ms/epoch - 1ms/step
# Epoch 609/1500
# 11/11 - 0s - loss: 21.7017 - 13ms/epoch - 1ms/step
# Epoch 610/1500
# 11/11 - 0s - loss: 22.3626 - 14ms/epoch - 1ms/step
# Epoch 611/1500
# 11/11 - 0s - loss: 22.1324 - 13ms/epoch - 1ms/step
# Epoch 612/1500
# 11/11 - 0s - loss: 21.2566 - 15ms/epoch - 1ms/step
# Epoch 613/1500
# 11/11 - 0s - loss: 22.1789 - 19ms/epoch - 2ms/step
# Epoch 614/1500
# 11/11 - 0s - loss: 21.1933 - 14ms/epoch - 1ms/step
# Epoch 615/1500
# 11/11 - 0s - loss: 21.1760 - 15ms/epoch - 1ms/step
# Epoch 616/1500
# 11/11 - 0s - loss: 20.9176 - 19ms/epoch - 2ms/step
# Epoch 617/1500
# 11/11 - 0s - loss: 22.4066 - 23ms/epoch - 2ms/step
# Epoch 618/1500
# 11/11 - 0s - loss: 21.0758 - 16ms/epoch - 1ms/step
# Epoch 619/1500
# 11/11 - 0s - loss: 21.2914 - 17ms/epoch - 2ms/step
# Epoch 620/1500
# 11/11 - 0s - loss: 21.7097 - 17ms/epoch - 2ms/step
# Epoch 621/1500
# 11/11 - 0s - loss: 21.2341 - 17ms/epoch - 2ms/step
# Epoch 622/1500
# 11/11 - 0s - loss: 20.9660 - 16ms/epoch - 1ms/step
# Epoch 623/1500
# 11/11 - 0s - loss: 20.8703 - 15ms/epoch - 1ms/step
# Epoch 624/1500
# 11/11 - 0s - loss: 20.7720 - 19ms/epoch - 2ms/step
# Epoch 625/1500
# 11/11 - 0s - loss: 21.5274 - 17ms/epoch - 2ms/step
# Epoch 626/1500
# 11/11 - 0s - loss: 21.4895 - 17ms/epoch - 2ms/step
# Epoch 627/1500
# 11/11 - 0s - loss: 21.3757 - 19ms/epoch - 2ms/step
# Epoch 628/1500
# 11/11 - 0s - loss: 20.4452 - 15ms/epoch - 1ms/step
# Epoch 629/1500
# 11/11 - 0s - loss: 20.7159 - 21ms/epoch - 2ms/step
# Epoch 630/1500
# 11/11 - 0s - loss: 20.9394 - 17ms/epoch - 2ms/step
# Epoch 631/1500
# 11/11 - 0s - loss: 22.5000 - 17ms/epoch - 2ms/step
# Epoch 632/1500
# 11/11 - 0s - loss: 21.6115 - 16ms/epoch - 1ms/step
# Epoch 633/1500
# 11/11 - 0s - loss: 21.5499 - 13ms/epoch - 1ms/step
# Epoch 634/1500
# 11/11 - 0s - loss: 25.7559 - 18ms/epoch - 2ms/step
# Epoch 635/1500
# 11/11 - 0s - loss: 22.5121 - 17ms/epoch - 2ms/step
# Epoch 636/1500
# 11/11 - 0s - loss: 20.4239 - 15ms/epoch - 1ms/step
# Epoch 637/1500
# 11/11 - 0s - loss: 21.8807 - 17ms/epoch - 2ms/step
# Epoch 638/1500
# 11/11 - 0s - loss: 21.5204 - 15ms/epoch - 1ms/step
# Epoch 639/1500
# 11/11 - 0s - loss: 21.4668 - 17ms/epoch - 2ms/step
# Epoch 640/1500
# 11/11 - 0s - loss: 21.7116 - 19ms/epoch - 2ms/step
# Epoch 641/1500
# 11/11 - 0s - loss: 20.8594 - 16ms/epoch - 1ms/step
# Epoch 642/1500
# 11/11 - 0s - loss: 21.6487 - 21ms/epoch - 2ms/step
# Epoch 643/1500
# 11/11 - 0s - loss: 22.6007 - 13ms/epoch - 1ms/step
# Epoch 644/1500
# 11/11 - 0s - loss: 20.7977 - 12ms/epoch - 1ms/step
# Epoch 645/1500
# 11/11 - 0s - loss: 20.3065 - 13ms/epoch - 1ms/step
# Epoch 646/1500
# 11/11 - 0s - loss: 20.4137 - 16ms/epoch - 1ms/step
# Epoch 647/1500
# 11/11 - 0s - loss: 20.7038 - 16ms/epoch - 1ms/step
# Epoch 648/1500
# 11/11 - 0s - loss: 20.8929 - 14ms/epoch - 1ms/step
# Epoch 649/1500
# 11/11 - 0s - loss: 21.4203 - 15ms/epoch - 1ms/step
# Epoch 650/1500
# 11/11 - 0s - loss: 22.2466 - 14ms/epoch - 1ms/step
# Epoch 651/1500
# 11/11 - 0s - loss: 20.6524 - 16ms/epoch - 1ms/step
# Epoch 652/1500
# 11/11 - 0s - loss: 21.8897 - 15ms/epoch - 1ms/step
# Epoch 653/1500
# 11/11 - 0s - loss: 20.5685 - 20ms/epoch - 2ms/step
# Epoch 654/1500
# 11/11 - 0s - loss: 20.6301 - 14ms/epoch - 1ms/step
# Epoch 655/1500
# 11/11 - 0s - loss: 20.3534 - 16ms/epoch - 1ms/step
# Epoch 656/1500
# 11/11 - 0s - loss: 20.5046 - 14ms/epoch - 1ms/step
# Epoch 657/1500
# 11/11 - 0s - loss: 21.2134 - 13ms/epoch - 1ms/step
# Epoch 658/1500
# 11/11 - 0s - loss: 20.5398 - 13ms/epoch - 1ms/step
# Epoch 659/1500
# 11/11 - 0s - loss: 20.6972 - 23ms/epoch - 2ms/step
# Epoch 660/1500
# 11/11 - 0s - loss: 22.8620 - 13ms/epoch - 1ms/step
# Epoch 661/1500
# 11/11 - 0s - loss: 21.8101 - 13ms/epoch - 1ms/step
# Epoch 662/1500
# 11/11 - 0s - loss: 20.1917 - 13ms/epoch - 1ms/step
# Epoch 663/1500
# 11/11 - 0s - loss: 21.9389 - 13ms/epoch - 1ms/step
# Epoch 664/1500
# 11/11 - 0s - loss: 20.9569 - 12ms/epoch - 1ms/step
# Epoch 665/1500
# 11/11 - 0s - loss: 21.7447 - 16ms/epoch - 1ms/step
# Epoch 666/1500
# 11/11 - 0s - loss: 21.0402 - 14ms/epoch - 1ms/step
# Epoch 667/1500
# 11/11 - 0s - loss: 20.3219 - 15ms/epoch - 1ms/step
# Epoch 668/1500
# 11/11 - 0s - loss: 20.2234 - 14ms/epoch - 1ms/step
# Epoch 669/1500
# 11/11 - 0s - loss: 20.4958 - 14ms/epoch - 1ms/step
# Epoch 670/1500
# 11/11 - 0s - loss: 20.3264 - 14ms/epoch - 1ms/step
# Epoch 671/1500
# 11/11 - 0s - loss: 19.9200 - 16ms/epoch - 1ms/step
# Epoch 672/1500
# 11/11 - 0s - loss: 21.3670 - 13ms/epoch - 1ms/step
# Epoch 673/1500
# 11/11 - 0s - loss: 20.3171 - 14ms/epoch - 1ms/step
# Epoch 674/1500
# 11/11 - 0s - loss: 20.3031 - 15ms/epoch - 1ms/step
# Epoch 675/1500
# 11/11 - 0s - loss: 19.9524 - 14ms/epoch - 1ms/step
# Epoch 676/1500
# 11/11 - 0s - loss: 19.8720 - 13ms/epoch - 1ms/step
# Epoch 677/1500
# 11/11 - 0s - loss: 20.9550 - 23ms/epoch - 2ms/step
# Epoch 678/1500
# 11/11 - 0s - loss: 19.9506 - 15ms/epoch - 1ms/step
# Epoch 679/1500
# 11/11 - 0s - loss: 19.8839 - 20ms/epoch - 2ms/step
# Epoch 680/1500
# 11/11 - 0s - loss: 20.4899 - 17ms/epoch - 2ms/step
# Epoch 681/1500
# 11/11 - 0s - loss: 21.9696 - 16ms/epoch - 1ms/step
# Epoch 682/1500
# 11/11 - 0s - loss: 21.0054 - 16ms/epoch - 1ms/step
# Epoch 683/1500
# 11/11 - 0s - loss: 19.9778 - 21ms/epoch - 2ms/step
# Epoch 684/1500
# 11/11 - 0s - loss: 20.5300 - 16ms/epoch - 1ms/step
# Epoch 685/1500
# 11/11 - 0s - loss: 22.0192 - 15ms/epoch - 1ms/step
# Epoch 686/1500
# 11/11 - 0s - loss: 19.7032 - 17ms/epoch - 2ms/step
# Epoch 687/1500
# 11/11 - 0s - loss: 20.5561 - 14ms/epoch - 1ms/step
# Epoch 688/1500
# 11/11 - 0s - loss: 21.0153 - 14ms/epoch - 1ms/step
# Epoch 689/1500
# 11/11 - 0s - loss: 20.6572 - 16ms/epoch - 1ms/step
# Epoch 690/1500
# 11/11 - 0s - loss: 20.5388 - 16ms/epoch - 1ms/step
# Epoch 691/1500
# 11/11 - 0s - loss: 21.0698 - 15ms/epoch - 1ms/step
# Epoch 692/1500
# 11/11 - 0s - loss: 19.8498 - 19ms/epoch - 2ms/step
# Epoch 693/1500
# 11/11 - 0s - loss: 19.9350 - 17ms/epoch - 2ms/step
# Epoch 694/1500
# 11/11 - 0s - loss: 19.2840 - 19ms/epoch - 2ms/step
# Epoch 695/1500
# 11/11 - 0s - loss: 19.3591 - 19ms/epoch - 2ms/step
# Epoch 696/1500
# 11/11 - 0s - loss: 19.5764 - 20ms/epoch - 2ms/step
# Epoch 697/1500
# 11/11 - 0s - loss: 19.5406 - 17ms/epoch - 2ms/step
# Epoch 698/1500
# 11/11 - 0s - loss: 21.6600 - 18ms/epoch - 2ms/step
# Epoch 699/1500
# 11/11 - 0s - loss: 21.9844 - 18ms/epoch - 2ms/step
# Epoch 700/1500
# 11/11 - 0s - loss: 19.7783 - 15ms/epoch - 1ms/step
# Epoch 701/1500
# 11/11 - 0s - loss: 19.7632 - 18ms/epoch - 2ms/step
# Epoch 702/1500
# 11/11 - 0s - loss: 18.9587 - 15ms/epoch - 1ms/step
# Epoch 703/1500
# 11/11 - 0s - loss: 19.6444 - 16ms/epoch - 1ms/step
# Epoch 704/1500
# 11/11 - 0s - loss: 20.5370 - 17ms/epoch - 2ms/step
# Epoch 705/1500
# 11/11 - 0s - loss: 19.4216 - 27ms/epoch - 2ms/step
# Epoch 706/1500
# 11/11 - 0s - loss: 19.0457 - 19ms/epoch - 2ms/step
# Epoch 707/1500
# 11/11 - 0s - loss: 19.3485 - 18ms/epoch - 2ms/step
# Epoch 708/1500
# 11/11 - 0s - loss: 20.0689 - 19ms/epoch - 2ms/step
# Epoch 709/1500
# 11/11 - 0s - loss: 19.6196 - 19ms/epoch - 2ms/step
# Epoch 710/1500
# 11/11 - 0s - loss: 19.2325 - 14ms/epoch - 1ms/step
# Epoch 711/1500
# 11/11 - 0s - loss: 19.2645 - 15ms/epoch - 1ms/step
# Epoch 712/1500
# 11/11 - 0s - loss: 19.4388 - 18ms/epoch - 2ms/step
# Epoch 713/1500
# 11/11 - 0s - loss: 23.8219 - 18ms/epoch - 2ms/step
# Epoch 714/1500
# 11/11 - 0s - loss: 24.5482 - 18ms/epoch - 2ms/step
# Epoch 715/1500
# 11/11 - 0s - loss: 20.0605 - 24ms/epoch - 2ms/step
# Epoch 716/1500
# 11/11 - 0s - loss: 20.1738 - 18ms/epoch - 2ms/step
# Epoch 717/1500
# 11/11 - 0s - loss: 19.0811 - 18ms/epoch - 2ms/step
# Epoch 718/1500
# 11/11 - 0s - loss: 19.2110 - 19ms/epoch - 2ms/step
# Epoch 719/1500
# 11/11 - 0s - loss: 20.1802 - 17ms/epoch - 2ms/step
# Epoch 720/1500
# 11/11 - 0s - loss: 20.4243 - 18ms/epoch - 2ms/step
# Epoch 721/1500
# 11/11 - 0s - loss: 19.7043 - 15ms/epoch - 1ms/step
# Epoch 722/1500
# 11/11 - 0s - loss: 19.4704 - 16ms/epoch - 1ms/step
# Epoch 723/1500
# 11/11 - 0s - loss: 19.5186 - 19ms/epoch - 2ms/step
# Epoch 724/1500
# 11/11 - 0s - loss: 19.4726 - 17ms/epoch - 2ms/step
# Epoch 725/1500
# 11/11 - 0s - loss: 19.9842 - 16ms/epoch - 1ms/step
# Epoch 726/1500
# 11/11 - 0s - loss: 18.7537 - 17ms/epoch - 2ms/step
# Epoch 727/1500
# 11/11 - 0s - loss: 19.4950 - 18ms/epoch - 2ms/step
# Epoch 728/1500
# 11/11 - 0s - loss: 18.5096 - 26ms/epoch - 2ms/step
# ...
# Epoch 1264/1500
# 11/11 - 0s - loss: 12.4158 - 16ms/epoch - 1ms/step
# Epoch 1265/1500
# 11/11 - 0s - loss: 12.0350 - 14ms/epoch - 1ms/step
# Epoch 1266/1500
# 11/11 - 0s - loss: 12.4055 - 16ms/epoch - 1ms/step
# Epoch 1267/1500
# 11/11 - 0s - loss: 12.3953 - 18ms/epoch - 2ms/step
# Epoch 1268/1500
# 11/11 - 0s - loss: 12.2288 - 19ms/epoch - 2ms/step
# Epoch 1269/1500
# 11/11 - 0s - loss: 11.9757 - 22ms/epoch - 2ms/step
# Epoch 1270/1500
# 11/11 - 0s - loss: 12.7034 - 17ms/epoch - 2ms/step
# Epoch 1271/1500
# 11/11 - 0s - loss: 12.2349 - 21ms/epoch - 2ms/step
# Epoch 1272/1500
# 11/11 - 0s - loss: 12.0564 - 15ms/epoch - 1ms/step
# Epoch 1273/1500
# 11/11 - 0s - loss: 11.8308 - 17ms/epoch - 2ms/step
# Epoch 1274/1500
# 11/11 - 0s - loss: 12.0529 - 22ms/epoch - 2ms/step
# Epoch 1275/1500
# 11/11 - 0s - loss: 12.3285 - 21ms/epoch - 2ms/step
# Epoch 1276/1500
# 11/11 - 0s - loss: 12.7084 - 18ms/epoch - 2ms/step
# Epoch 1277/1500
# 11/11 - 0s - loss: 12.8123 - 22ms/epoch - 2ms/step
# Epoch 1278/1500
# 11/11 - 0s - loss: 12.9983 - 16ms/epoch - 1ms/step
# Epoch 1279/1500
# 11/11 - 0s - loss: 12.1863 - 15ms/epoch - 1ms/step
# Epoch 1280/1500
# 11/11 - 0s - loss: 12.2748 - 15ms/epoch - 1ms/step
# Epoch 1281/1500
# 11/11 - 0s - loss: 12.1008 - 17ms/epoch - 2ms/step
# Epoch 1282/1500
# 11/11 - 0s - loss: 13.3516 - 19ms/epoch - 2ms/step
# Epoch 1283/1500
# 11/11 - 0s - loss: 12.5208 - 16ms/epoch - 1ms/step
# Epoch 1284/1500
# 11/11 - 0s - loss: 12.7574 - 18ms/epoch - 2ms/step
# Epoch 1285/1500
# 11/11 - 0s - loss: 11.6707 - 14ms/epoch - 1ms/step
# Epoch 1286/1500
# 11/11 - 0s - loss: 11.9568 - 19ms/epoch - 2ms/step
# Epoch 1287/1500
# 11/11 - 0s - loss: 12.0297 - 18ms/epoch - 2ms/step
# Epoch 1288/1500
# 11/11 - 0s - loss: 11.9929 - 14ms/epoch - 1ms/step
# Epoch 1289/1500
# 11/11 - 0s - loss: 12.1043 - 19ms/epoch - 2ms/step
# Epoch 1290/1500
# 11/11 - 0s - loss: 11.8261 - 16ms/epoch - 1ms/step
# Epoch 1291/1500
# 11/11 - 0s - loss: 12.0013 - 16ms/epoch - 1ms/step
# Epoch 1292/1500
# 11/11 - 0s - loss: 12.0021 - 17ms/epoch - 2ms/step
# Epoch 1293/1500
# 11/11 - 0s - loss: 12.4664 - 22ms/epoch - 2ms/step
# Epoch 1294/1500
# 11/11 - 0s - loss: 12.5674 - 17ms/epoch - 2ms/step
# Epoch 1295/1500
# 11/11 - 0s - loss: 12.0558 - 22ms/epoch - 2ms/step
# Epoch 1296/1500
# 11/11 - 0s - loss: 12.5097 - 16ms/epoch - 1ms/step
# Epoch 1297/1500
# 11/11 - 0s - loss: 11.8378 - 18ms/epoch - 2ms/step
# Epoch 1298/1500
# 11/11 - 0s - loss: 11.9591 - 23ms/epoch - 2ms/step
# Epoch 1299/1500
# 11/11 - 0s - loss: 11.6371 - 19ms/epoch - 2ms/step
# Epoch 1300/1500
# 11/11 - 0s - loss: 11.9651 - 17ms/epoch - 2ms/step
# Epoch 1301/1500
# 11/11 - 0s - loss: 12.2214 - 15ms/epoch - 1ms/step
# Epoch 1302/1500
# 11/11 - 0s - loss: 12.4064 - 14ms/epoch - 1ms/step
# Epoch 1303/1500
# 11/11 - 0s - loss: 12.9602 - 14ms/epoch - 1ms/step
# Epoch 1304/1500
# 11/11 - 0s - loss: 12.5358 - 17ms/epoch - 2ms/step
# Epoch 1305/1500
# 11/11 - 0s - loss: 12.4632 - 16ms/epoch - 1ms/step
# Epoch 1306/1500
# 11/11 - 0s - loss: 11.6680 - 15ms/epoch - 1ms/step
# Epoch 1307/1500
# 11/11 - 0s - loss: 12.6575 - 14ms/epoch - 1ms/step
# Epoch 1308/1500
# 11/11 - 0s - loss: 12.1095 - 15ms/epoch - 1ms/step
# Epoch 1309/1500
# 11/11 - 0s - loss: 12.1774 - 15ms/epoch - 1ms/step
# Epoch 1310/1500
# 11/11 - 0s - loss: 12.4390 - 15ms/epoch - 1ms/step
# Epoch 1311/1500
# 11/11 - 0s - loss: 12.1351 - 19ms/epoch - 2ms/step
# Epoch 1312/1500
# 11/11 - 0s - loss: 11.8187 - 18ms/epoch - 2ms/step
# Epoch 1313/1500
# 11/11 - 0s - loss: 12.0340 - 19ms/epoch - 2ms/step
# Epoch 1314/1500
# 11/11 - 0s - loss: 11.9393 - 20ms/epoch - 2ms/step
# Epoch 1315/1500
# 11/11 - 0s - loss: 11.8761 - 15ms/epoch - 1ms/step
# Epoch 1316/1500
# 11/11 - 0s - loss: 12.6049 - 20ms/epoch - 2ms/step
# Epoch 1317/1500
# 11/11 - 0s - loss: 12.3113 - 21ms/epoch - 2ms/step
# Epoch 1318/1500
# 11/11 - 0s - loss: 11.7218 - 19ms/epoch - 2ms/step
# Epoch 1319/1500
# 11/11 - 0s - loss: 12.0054 - 21ms/epoch - 2ms/step
# Epoch 1320/1500
# 11/11 - 0s - loss: 11.8973 - 20ms/epoch - 2ms/step
# Epoch 1321/1500
# 11/11 - 0s - loss: 11.6576 - 18ms/epoch - 2ms/step
# Epoch 1322/1500
# 11/11 - 0s - loss: 12.7236 - 16ms/epoch - 1ms/step
# Epoch 1323/1500
# 11/11 - 0s - loss: 12.4337 - 18ms/epoch - 2ms/step
# Epoch 1324/1500
# 11/11 - 0s - loss: 12.0122 - 17ms/epoch - 2ms/step
# Epoch 1325/1500
# 11/11 - 0s - loss: 11.9059 - 21ms/epoch - 2ms/step
# Epoch 1326/1500
# 11/11 - 0s - loss: 12.1624 - 16ms/epoch - 1ms/step
# Epoch 1327/1500
# 11/11 - 0s - loss: 11.5484 - 16ms/epoch - 1ms/step
# Epoch 1328/1500
# 11/11 - 0s - loss: 12.8823 - 17ms/epoch - 2ms/step
# Epoch 1329/1500
# 11/11 - 0s - loss: 15.2569 - 15ms/epoch - 1ms/step
# Epoch 1330/1500
# 11/11 - 0s - loss: 13.4948 - 17ms/epoch - 2ms/step
# Epoch 1331/1500
# 11/11 - 0s - loss: 14.0409 - 18ms/epoch - 2ms/step
# Epoch 1332/1500
# 11/11 - 0s - loss: 13.8400 - 20ms/epoch - 2ms/step
# Epoch 1333/1500
# 11/11 - 0s - loss: 11.8193 - 15ms/epoch - 1ms/step
# Epoch 1334/1500
# 11/11 - 0s - loss: 12.9153 - 16ms/epoch - 1ms/step
# Epoch 1335/1500
# 11/11 - 0s - loss: 12.1131 - 13ms/epoch - 1ms/step
# Epoch 1336/1500
# 11/11 - 0s - loss: 11.4737 - 15ms/epoch - 1ms/step
# Epoch 1337/1500
# 11/11 - 0s - loss: 11.8317 - 18ms/epoch - 2ms/step
# Epoch 1338/1500
# 11/11 - 0s - loss: 12.1233 - 16ms/epoch - 1ms/step
# Epoch 1339/1500
# 11/11 - 0s - loss: 11.2610 - 17ms/epoch - 2ms/step
# Epoch 1340/1500
# 11/11 - 0s - loss: 11.5859 - 19ms/epoch - 2ms/step
# Epoch 1341/1500
# 11/11 - 0s - loss: 13.6463 - 15ms/epoch - 1ms/step
# Epoch 1342/1500
# 11/11 - 0s - loss: 13.0717 - 15ms/epoch - 1ms/step
# Epoch 1343/1500
# 11/11 - 0s - loss: 12.0439 - 15ms/epoch - 1ms/step
# Epoch 1344/1500
# 11/11 - 0s - loss: 11.8521 - 15ms/epoch - 1ms/step
# Epoch 1345/1500
# 11/11 - 0s - loss: 11.5268 - 15ms/epoch - 1ms/step
# Epoch 1346/1500
# 11/11 - 0s - loss: 11.2380 - 15ms/epoch - 1ms/step
# Epoch 1347/1500
# 11/11 - 0s - loss: 11.6124 - 14ms/epoch - 1ms/step
# Epoch 1348/1500
# 11/11 - 0s - loss: 11.4447 - 13ms/epoch - 1ms/step
# Epoch 1349/1500
# 11/11 - 0s - loss: 11.8054 - 14ms/epoch - 1ms/step
# Epoch 1350/1500
# 11/11 - 0s - loss: 12.1282 - 15ms/epoch - 1ms/step
# Epoch 1351/1500
# 11/11 - 0s - loss: 11.7034 - 15ms/epoch - 1ms/step
# Epoch 1352/1500
# 11/11 - 0s - loss: 12.0548 - 17ms/epoch - 2ms/step
# Epoch 1353/1500
# 11/11 - 0s - loss: 11.7098 - 18ms/epoch - 2ms/step
# Epoch 1354/1500
# 11/11 - 0s - loss: 11.4039 - 20ms/epoch - 2ms/step
# Epoch 1355/1500
# 11/11 - 0s - loss: 11.6077 - 16ms/epoch - 1ms/step
# Epoch 1356/1500
# 11/11 - 0s - loss: 12.1795 - 17ms/epoch - 2ms/step
# Epoch 1357/1500
# 11/11 - 0s - loss: 12.6755 - 23ms/epoch - 2ms/step
# Epoch 1358/1500
# 11/11 - 0s - loss: 13.0151 - 16ms/epoch - 1ms/step
# Epoch 1359/1500
# 11/11 - 0s - loss: 12.0954 - 17ms/epoch - 2ms/step
# Epoch 1360/1500
# 11/11 - 0s - loss: 11.8979 - 17ms/epoch - 2ms/step
# Epoch 1361/1500
# 11/11 - 0s - loss: 11.4940 - 18ms/epoch - 2ms/step
# Epoch 1362/1500
# 11/11 - 0s - loss: 11.7880 - 17ms/epoch - 2ms/step
# Epoch 1363/1500
# 11/11 - 0s - loss: 11.7037 - 16ms/epoch - 1ms/step
# Epoch 1364/1500
# 11/11 - 0s - loss: 11.6126 - 19ms/epoch - 2ms/step
# Epoch 1365/1500
# 11/11 - 0s - loss: 11.7200 - 18ms/epoch - 2ms/step
# Epoch 1366/1500
# 11/11 - 0s - loss: 12.1133 - 16ms/epoch - 1ms/step
# Epoch 1367/1500
# 11/11 - 0s - loss: 11.4351 - 20ms/epoch - 2ms/step
# Epoch 1368/1500
# 11/11 - 0s - loss: 13.3145 - 16ms/epoch - 1ms/step
# Epoch 1369/1500
# 11/11 - 0s - loss: 12.2788 - 17ms/epoch - 2ms/step
# Epoch 1370/1500
# 11/11 - 0s - loss: 11.6086 - 20ms/epoch - 2ms/step
# Epoch 1371/1500
# 11/11 - 0s - loss: 11.7236 - 23ms/epoch - 2ms/step
# Epoch 1372/1500
# 11/11 - 0s - loss: 11.3228 - 18ms/epoch - 2ms/step
# Epoch 1373/1500
# 11/11 - 0s - loss: 12.0152 - 19ms/epoch - 2ms/step
# Epoch 1374/1500
# 11/11 - 0s - loss: 11.3937 - 16ms/epoch - 1ms/step
# Epoch 1375/1500
# 11/11 - 0s - loss: 11.3700 - 23ms/epoch - 2ms/step
# Epoch 1376/1500
# 11/11 - 0s - loss: 12.1485 - 18ms/epoch - 2ms/step
# Epoch 1377/1500
# 11/11 - 0s - loss: 13.0508 - 18ms/epoch - 2ms/step
# Epoch 1378/1500
# 11/11 - 0s - loss: 14.1105 - 22ms/epoch - 2ms/step
# Epoch 1379/1500
# 11/11 - 0s - loss: 11.9173 - 18ms/epoch - 2ms/step
# Epoch 1380/1500
# 11/11 - 0s - loss: 12.8531 - 17ms/epoch - 2ms/step
# Epoch 1381/1500
# 11/11 - 0s - loss: 11.8087 - 17ms/epoch - 2ms/step
# Epoch 1382/1500
# 11/11 - 0s - loss: 11.7834 - 16ms/epoch - 1ms/step
# Epoch 1383/1500
# 11/11 - 0s - loss: 12.3659 - 18ms/epoch - 2ms/step
# Epoch 1384/1500
# 11/11 - 0s - loss: 11.3405 - 16ms/epoch - 1ms/step
# Epoch 1385/1500
# 11/11 - 0s - loss: 11.4316 - 15ms/epoch - 1ms/step
# Epoch 1386/1500
# 11/11 - 0s - loss: 11.7372 - 13ms/epoch - 1ms/step
# Epoch 1387/1500
# 11/11 - 0s - loss: 11.4841 - 14ms/epoch - 1ms/step
# Epoch 1388/1500
# 11/11 - 0s - loss: 11.3255 - 16ms/epoch - 1ms/step
# Epoch 1389/1500
# 11/11 - 0s - loss: 12.0071 - 14ms/epoch - 1ms/step
# Epoch 1390/1500
# 11/11 - 0s - loss: 12.1907 - 14ms/epoch - 1ms/step
# Epoch 1391/1500
# 11/11 - 0s - loss: 13.5729 - 15ms/epoch - 1ms/step
# Epoch 1392/1500
# 11/11 - 0s - loss: 13.2926 - 13ms/epoch - 1ms/step
# Epoch 1393/1500
# 11/11 - 0s - loss: 11.5657 - 14ms/epoch - 1ms/step
# Epoch 1394/1500
# 11/11 - 0s - loss: 11.3050 - 14ms/epoch - 1ms/step
# Epoch 1395/1500
# 11/11 - 0s - loss: 11.1921 - 13ms/epoch - 1ms/step
# Epoch 1396/1500
# 11/11 - 0s - loss: 11.4396 - 17ms/epoch - 2ms/step
# Epoch 1397/1500
# 11/11 - 0s - loss: 12.5478 - 16ms/epoch - 1ms/step
# Epoch 1398/1500
# 11/11 - 0s - loss: 11.7519 - 22ms/epoch - 2ms/step
# Epoch 1399/1500
# 11/11 - 0s - loss: 11.5051 - 18ms/epoch - 2ms/step
# Epoch 1400/1500
# 11/11 - 0s - loss: 11.1123 - 21ms/epoch - 2ms/step
# Epoch 1401/1500
# 11/11 - 0s - loss: 11.1397 - 18ms/epoch - 2ms/step
# Epoch 1402/1500
# 11/11 - 0s - loss: 11.0841 - 17ms/epoch - 2ms/step
# Epoch 1403/1500
# 11/11 - 0s - loss: 11.2670 - 18ms/epoch - 2ms/step
# Epoch 1404/1500
# 11/11 - 0s - loss: 11.2149 - 17ms/epoch - 2ms/step
# Epoch 1405/1500
# 11/11 - 0s - loss: 11.3246 - 22ms/epoch - 2ms/step
# Epoch 1406/1500
# 11/11 - 0s - loss: 12.6800 - 16ms/epoch - 1ms/step
# Epoch 1407/1500
# 11/11 - 0s - loss: 13.1634 - 19ms/epoch - 2ms/step
# Epoch 1408/1500
# 11/11 - 0s - loss: 12.7862 - 19ms/epoch - 2ms/step
# Epoch 1409/1500
# 11/11 - 0s - loss: 11.9122 - 20ms/epoch - 2ms/step
# Epoch 1410/1500
# 11/11 - 0s - loss: 11.5297 - 16ms/epoch - 1ms/step
# Epoch 1411/1500
# 11/11 - 0s - loss: 11.6915 - 19ms/epoch - 2ms/step
# Epoch 1412/1500
# 11/11 - 0s - loss: 14.4028 - 17ms/epoch - 2ms/step
# Epoch 1413/1500
# 11/11 - 0s - loss: 12.5974 - 22ms/epoch - 2ms/step
# Epoch 1414/1500
# 11/11 - 0s - loss: 11.3268 - 17ms/epoch - 2ms/step
# Epoch 1415/1500
# 11/11 - 0s - loss: 10.9007 - 29ms/epoch - 3ms/step
# Epoch 1416/1500
# 11/11 - 0s - loss: 11.0457 - 17ms/epoch - 2ms/step
# Epoch 1417/1500
# 11/11 - 0s - loss: 11.2502 - 16ms/epoch - 1ms/step
# Epoch 1418/1500
# 11/11 - 0s - loss: 11.4712 - 15ms/epoch - 1ms/step
# Epoch 1419/1500
# 11/11 - 0s - loss: 11.3491 - 16ms/epoch - 1ms/step
# Epoch 1420/1500
# 11/11 - 0s - loss: 11.2233 - 15ms/epoch - 1ms/step
# Epoch 1421/1500
# 11/11 - 0s - loss: 10.9796 - 15ms/epoch - 1ms/step
# Epoch 1422/1500
# 11/11 - 0s - loss: 11.2000 - 19ms/epoch - 2ms/step
# Epoch 1423/1500
# 11/11 - 0s - loss: 11.2931 - 21ms/epoch - 2ms/step
# Epoch 1424/1500
# 11/11 - 0s - loss: 11.5573 - 20ms/epoch - 2ms/step
# Epoch 1425/1500
# 11/11 - 0s - loss: 13.0722 - 23ms/epoch - 2ms/step
# Epoch 1426/1500
# 11/11 - 0s - loss: 12.7587 - 18ms/epoch - 2ms/step
# Epoch 1427/1500
# 11/11 - 0s - loss: 11.2813 - 15ms/epoch - 1ms/step
# Epoch 1428/1500
# 11/11 - 0s - loss: 11.3985 - 17ms/epoch - 2ms/step
# Epoch 1429/1500
# 11/11 - 0s - loss: 11.4566 - 16ms/epoch - 1ms/step
# Epoch 1430/1500
# 11/11 - 0s - loss: 11.4901 - 17ms/epoch - 2ms/step
# Epoch 1431/1500
# 11/11 - 0s - loss: 12.6579 - 16ms/epoch - 1ms/step
# Epoch 1432/1500
# 11/11 - 0s - loss: 12.2708 - 17ms/epoch - 2ms/step
# Epoch 1433/1500
# 11/11 - 0s - loss: 11.3525 - 14ms/epoch - 1ms/step
# Epoch 1434/1500
# 11/11 - 0s - loss: 12.9480 - 14ms/epoch - 1ms/step
# Epoch 1435/1500
# 11/11 - 0s - loss: 13.0577 - 14ms/epoch - 1ms/step
# Epoch 1436/1500
# 11/11 - 0s - loss: 12.0209 - 15ms/epoch - 1ms/step
# Epoch 1437/1500
# 11/11 - 0s - loss: 12.1566 - 14ms/epoch - 1ms/step
# Epoch 1438/1500
# 11/11 - 0s - loss: 11.2132 - 14ms/epoch - 1ms/step
# Epoch 1439/1500
# 11/11 - 0s - loss: 11.2826 - 14ms/epoch - 1ms/step
# Epoch 1440/1500
# 11/11 - 0s - loss: 12.8512 - 16ms/epoch - 1ms/step
# Epoch 1441/1500
# 11/11 - 0s - loss: 11.8573 - 13ms/epoch - 1ms/step
# Epoch 1442/1500
# 11/11 - 0s - loss: 11.3053 - 22ms/epoch - 2ms/step
# Epoch 1443/1500
# 11/11 - 0s - loss: 11.9853 - 23ms/epoch - 2ms/step
# Epoch 1444/1500
# 11/11 - 0s - loss: 10.8359 - 14ms/epoch - 1ms/step
# Epoch 1445/1500
# 11/11 - 0s - loss: 11.2322 - 15ms/epoch - 1ms/step
# Epoch 1446/1500
# 11/11 - 0s - loss: 11.3577 - 15ms/epoch - 1ms/step
# Epoch 1447/1500
# 11/11 - 0s - loss: 10.9585 - 16ms/epoch - 1ms/step
# Epoch 1448/1500
# 11/11 - 0s - loss: 11.5222 - 17ms/epoch - 2ms/step
# Epoch 1449/1500
# 11/11 - 0s - loss: 11.4964 - 13ms/epoch - 1ms/step
# Epoch 1450/1500
# 11/11 - 0s - loss: 13.1788 - 14ms/epoch - 1ms/step
# Epoch 1451/1500
# 11/11 - 0s - loss: 12.8708 - 14ms/epoch - 1ms/step
# Epoch 1452/1500
# 11/11 - 0s - loss: 12.0472 - 15ms/epoch - 1ms/step
# Epoch 1453/1500
# 11/11 - 0s - loss: 11.4402 - 14ms/epoch - 1ms/step
# Epoch 1454/1500
# 11/11 - 0s - loss: 11.5866 - 15ms/epoch - 1ms/step
# Epoch 1455/1500
# 11/11 - 0s - loss: 11.2876 - 14ms/epoch - 1ms/step
# Epoch 1456/1500
# 11/11 - 0s - loss: 11.8314 - 15ms/epoch - 1ms/step
# Epoch 1457/1500
# 11/11 - 0s - loss: 11.6689 - 19ms/epoch - 2ms/step
# Epoch 1458/1500
# 11/11 - 0s - loss: 11.5027 - 14ms/epoch - 1ms/step
# Epoch 1459/1500
# 11/11 - 0s - loss: 11.8096 - 14ms/epoch - 1ms/step
# Epoch 1460/1500
# 11/11 - 0s - loss: 13.2416 - 17ms/epoch - 2ms/step
# Epoch 1461/1500
# 11/11 - 0s - loss: 11.3870 - 17ms/epoch - 2ms/step
# Epoch 1462/1500
# 11/11 - 0s - loss: 11.0307 - 15ms/epoch - 1ms/step
# Epoch 1463/1500
# 11/11 - 0s - loss: 11.2581 - 21ms/epoch - 2ms/step
# Epoch 1464/1500
# 11/11 - 0s - loss: 12.9092 - 17ms/epoch - 2ms/step
# Epoch 1465/1500
# 11/11 - 0s - loss: 11.5561 - 16ms/epoch - 1ms/step
# Epoch 1466/1500
# 11/11 - 0s - loss: 11.3810 - 16ms/epoch - 1ms/step
# Epoch 1467/1500
# 11/11 - 0s - loss: 11.1111 - 15ms/epoch - 1ms/step
# Epoch 1468/1500
# 11/11 - 0s - loss: 10.9884 - 16ms/epoch - 1ms/step
# Epoch 1469/1500
# 11/11 - 0s - loss: 10.6246 - 15ms/epoch - 1ms/step
# Epoch 1470/1500
# 11/11 - 0s - loss: 11.0411 - 13ms/epoch - 1ms/step
# Epoch 1471/1500
# 11/11 - 0s - loss: 11.1008 - 13ms/epoch - 1ms/step
# Epoch 1472/1500
# 11/11 - 0s - loss: 11.1017 - 14ms/epoch - 1ms/step
# Epoch 1473/1500
# 11/11 - 0s - loss: 12.8723 - 15ms/epoch - 1ms/step
# Epoch 1474/1500
# 11/11 - 0s - loss: 12.4172 - 14ms/epoch - 1ms/step
# Epoch 1475/1500
# 11/11 - 0s - loss: 11.7121 - 14ms/epoch - 1ms/step
# Epoch 1476/1500
# 11/11 - 0s - loss: 11.8274 - 15ms/epoch - 1ms/step
# Epoch 1477/1500
# 11/11 - 0s - loss: 11.0695 - 14ms/epoch - 1ms/step
# Epoch 1478/1500
# 11/11 - 0s - loss: 10.6624 - 15ms/epoch - 1ms/step
# Epoch 1479/1500
# 11/11 - 0s - loss: 10.9632 - 15ms/epoch - 1ms/step
# Epoch 1480/1500
# 11/11 - 0s - loss: 10.6803 - 25ms/epoch - 2ms/step
# Epoch 1481/1500
# 11/11 - 0s - loss: 11.0861 - 17ms/epoch - 2ms/step
# Epoch 1482/1500
# 11/11 - 0s - loss: 11.5846 - 19ms/epoch - 2ms/step
# Epoch 1483/1500
# 11/11 - 0s - loss: 11.2238 - 16ms/epoch - 1ms/step
# Epoch 1484/1500
# 11/11 - 0s - loss: 11.4262 - 17ms/epoch - 2ms/step
# Epoch 1485/1500
# 11/11 - 0s - loss: 12.0425 - 17ms/epoch - 2ms/step
# Epoch 1486/1500
# 11/11 - 0s - loss: 12.2694 - 18ms/epoch - 2ms/step
# Epoch 1487/1500
# 11/11 - 0s - loss: 10.7543 - 18ms/epoch - 2ms/step
# Epoch 1488/1500
# 11/11 - 0s - loss: 10.8009 - 15ms/epoch - 1ms/step
# Epoch 1489/1500
# 11/11 - 0s - loss: 10.8446 - 17ms/epoch - 2ms/step
# Epoch 1490/1500
# 11/11 - 0s - loss: 10.7432 - 17ms/epoch - 2ms/step
# Epoch 1491/1500
# 11/11 - 0s - loss: 10.6562 - 16ms/epoch - 1ms/step
# Epoch 1492/1500
# 11/11 - 0s - loss: 10.5004 - 15ms/epoch - 1ms/step
# Epoch 1493/1500
# 11/11 - 0s - loss: 11.9807 - 17ms/epoch - 2ms/step
# Epoch 1494/1500
# 11/11 - 0s - loss: 11.5656 - 15ms/epoch - 1ms/step
# Epoch 1495/1500
# 11/11 - 0s - loss: 13.4611 - 16ms/epoch - 1ms/step
# Epoch 1496/1500
# 11/11 - 0s - loss: 14.7338 - 22ms/epoch - 2ms/step
# Epoch 1497/1500
# 11/11 - 0s - loss: 11.5159 - 17ms/epoch - 2ms/step
# Epoch 1498/1500
# 11/11 - 0s - loss: 11.3931 - 16ms/epoch - 1ms/step
# Epoch 1499/1500
# 11/11 - 0s - loss: 12.1020 - 15ms/epoch - 1ms/step
# Epoch 1500/1500
# 11/11 - 0s - loss: 11.0027 - 15ms/epoch - 1ms/step
# MSE: 13.204, RMSE: 3.634
# 1/1 [==============================] - 0s 87ms/step
# Predicted: 29.987
